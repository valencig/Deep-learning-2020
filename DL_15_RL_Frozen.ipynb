# %%
# Source: https://towardsdatascience.com/reinforcement-learning-with-ohttps://github.com/openai/gym/wiki/Environmentspenai-d445c2c687d2
#
# https://gym.openai.com/envs/#classic_control
# https://github.com/openai/gym/wiki/Environments

# conda install -n py37 gym[atari] -c conda-forge
# conda install -n py37 gym[all] -c conda-forge
# conda install -n py37 atari_py -c conda-forge
# conda install -n py37 pybox2d -c conda-forge

# Acrobot-v1
# CartPole-v0
# MountainCar-v0
# MountainCarContinuous-v0

# Pong-v0
# MsPacman-v0

# CarRacing-v0

# FrozenLake8x8-v0

# %% [markdown]
# # DE AQUI

# %%
# https://deeplizard.com/learn/video/a-SnJtmBtyA
# https://www.youtube.com/watch?v=nyjbcRQ-uQ8&list=PLZbbT5o_s2xoWNVdDudn51XM8lOuZ_Njv

# https://pythonprogramming.net/deep-q-learning-dqn-reinforcement-learning-python-tutorial/
# https://www.freecodecamp.org/news/an-introduction-to-deep-q-learning-lets-play-doom-54d02d8017d8/
# https://simoninithomas.github.io/Deep_reinforcement_learning_Course/
# https://lilianweng.github.io/lil-log/2018/05/05/implementing-deep-reinforcement-learning-models.html

# %%
import numpy as np
import random
import gym
from itertools import count
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Create an environment for a chosen game -- see docs for more games
env = gym.make('FrozenLake-v0', is_slippery=False)
env.close()

# %%
# Agent i/o parameters
in_shape = env.observation_space.n # Size of state space
print(f"State space length: {in_shape}")
out_shape = env.action_space.n         # Size of action space
print(f"Action space length: {out_shape}")
# Out:
# State space length: 16
# Action space length: 4

# %%
def create_agent():
  '''Definition of agent'''
  model = Sequential()
  model.add(Dense(16, input_shape=(in_shape,), activation='relu', kernel_initializer='he_normal', use_bias=False))
  model.add(Dense(64, activation='relu', kernel_initializer='he_normal', use_bias=False))
  model.add(Dense(16, activation='relu', kernel_initializer='he_normal', use_bias=False))
  model.add(Dense(out_shape, activation='linear', kernel_initializer='he_normal', use_bias=False))
  model.compile(loss="hinge", optimizer=Adam(learning_rate=0.005))
  return model

# %%
def sample_action(state, eps):
  ''' Generate an action.
      Given the current exploration rate (defined by the number of samples taken
      so far, 'global samples_taken'), the action can be generated either
      by exploration (random) or exploitation (using current knowledge,
      i.e., current model and current state, 'state').
  '''
  # Sample by exploitation or exploration
  if np.random.uniform() > eps:
      state = to_categorical(state, in_shape).reshape(-1, in_shape) # adjust accordinly
      action = np.argmax(net_policy.predict(state))
  else:
      action = env.action_space.sample()
  return action

# %%
def init_mem_replay():
  experience = {"state": 0,
                "action": 0,
                "reward": 0,
                "next_state": 0
                }
  return [experience for _ in range(memory_len)]

# %%
def push_experience(state, action, reward, next_state, done):
  '''
  Stores experience in replay memory.
  Values of experience are encapsulated into a dictionary.
  Append if replay memory has not yet reached max length, or
  replace oldest register.
  '''
  experience = {"state": state,
                "action": action,
                "reward": reward,
                "next_state": next_state,
                "done": done
                }
  replay_mem[push_count % memory_len] = experience

# %%
def decouple_batch(batch):
  states = []
  actions = []
  rewards = []
  next_states = []
  dones = []
  for experience in batch:
    states.append(experience['state'])
    actions.append(experience['action'])
    rewards.append(experience['reward'])
    next_states.append(experience['next_state'])
    dones.append(experience['done'])
  return np.array(states), np.array(actions), np.array(rewards), np.array(next_states), np.array(dones)

# %%
# Train - initialize environment
env = gym.make('FrozenLake-v0', is_slippery=False)

# Parameters
n_episodes = 2000
batch_size = 64
memory_len = 50_000
gamma = 0.99
update_rate = 10

# Exploration/exploitation rate parameters
EPS_START = 1.0
EPS_END = 0.01
EPS_DECAY = 0.98

# Initialize agent
net_policy = create_agent()
net_target = create_agent()
net_target.set_weights(net_policy.get_weights())

# Variables
replay_mem = init_mem_replay()
eps = EPS_START
push_count = 0
n_wins, max_wins = 0, 0 # Count consecutive wins
loss = 1.

# Start training
for episode in range(n_episodes):
  print(f"Episode:{episode+1:4d}/{n_episodes} --", end=' ')

  # Reset environment and get initial state
  state = env.reset()
  for t_step in count():
    # Probability of exploration/exploitation. And number of samples already taken
    eps *= EPS_DECAY
    if eps < EPS_END:
      eps = EPS_START

    # Simulate one time step
    action = sample_action(state, eps)                # Sample and action with prob eps
    next_state, reward, done, info = env.step(action)      # Evaluate sampled action

    # Adjust reward (custom reward function)
    if done and reward == 0:    # Lost
      reward = -20
    elif done and reward == 1:  # Win
      reward = 20
    else:                       # Just still alive
      reward = -0.1 * t_step

    # Store experience in replay memory
    push_experience(state, action, reward, next_state, done)    # Push new experience into replay memory
    push_count += 1                                             # Update count of pushes into memory
    state = next_state                                          # Update state as given by the last action

    if push_count >= batch_size:
      # sample a random batch from replay memory
      lim_mem = min(push_count, memory_len)
      batch = random.sample(replay_mem[:lim_mem], batch_size)
      batch_states, batch_actions, batch_rewards, batch_next_states, batch_dones = decouple_batch(batch)

      # Compute q-values for current and next state, and update for the chosen action
      batch_states = to_categorical(batch_states, in_shape)
      batch_next_states = to_categorical(batch_next_states, in_shape)
      q_vals = net_policy.predict(batch_states)
      q_vals_next = net_target.predict(batch_next_states)

      # Updte Q-values by Bellman equation (general update vs wins)
      for q_ind, (don, act, rew, q_next) in enumerate(zip(batch_dones, batch_actions, batch_rewards, q_vals_next)):
        if not don:
          q_vals[q_ind, act] = rew + gamma * q_next.max()
        else:
          q_vals[q_ind, act] = rew

      # Retrain network
      loss = net_policy.train_on_batch(batch_states, q_vals)

    # Check for episode termination
    if done:
      break

  # Update target network
  if episode % update_rate == 0:
    net_target.set_weights(net_policy.get_weights())
  
  # Print episode's info
  if reward <= 0:
    print(" failed  ", end=' ')
    n_wins = 0
  elif reward > 0:
    print("*success*", end=' ')
    n_wins += 1
  max_wins = max(max_wins, n_wins)
  print(f"(wins={n_wins:2d}/{max_wins:2d})", end=' ')
  print(f"in {t_step+1:3d} t-steps, @state {state:2d}, eps={eps:.2f}({push_count:6d}), loss={loss:.4f}")
  
env.close()
# Out:
# Episode:   1/2000 --  failed   (wins= 0/ 0) in   3 t-steps, @state  5, eps=0.94(     3), loss=1.0000
# Episode:   2/2000 --  failed   (wins= 0/ 0) in   5 t-steps, @state 12, eps=0.85(     8), loss=1.0000
# Episode:   3/2000 --  failed   (wins= 0/ 0) in   4 t-steps, @state  5, eps=0.78(    12), loss=1.0000
# Episode:   4/2000 --  failed   (wins= 0/ 0) in   6 t-steps, @state 12, eps=0.70(    18), loss=1.0000
# Episode:   5/2000 --  failed   (wins= 0/ 0) in   2 t-steps, @state  5, eps=0.67(    20), loss=1.0000
# Episode:   6/2000 --  failed   (wins= 0/ 0) in  10 t-steps, @state 12, eps=0.55(    30), loss=1.0000
# Episode:   7/2000 --  failed   (wins= 0/ 0) in   8 t-steps, @state  7, eps=0.46(    38), loss=1.0000
# Episode:   8/2000 --  failed   (wins= 0/ 0) in   2 t-steps, @state  5, eps=0.45(    40), loss=1.0000
# Episode:   9/2000 -- *success* (wins= 1/ 1) in   9 t-steps, @state 15, eps=0.37(    49), loss=1.0000
# Episode:  10/2000 --  failed   (wins= 0/ 1) in   6 t-steps, @state  7, eps=0.33(    55), loss=1.0000
# Episode:  11/2000 --  failed   (wins= 0/ 1) in  47 t-steps, @state  5, eps=0.13(   102), loss=0.2161
# Episode:  12/2000 --  failed   (wins= 0/ 1) in  26 t-steps, @state  7, eps=0.08(   128), loss=0.1318
# Episode:  13/2000 --  failed   (wins= 0/ 1) in  38 t-steps, @state 11, eps=0.03(   166), loss=0.2512
# Episode:  14/2000 --  failed   (wins= 0/ 1) in  67 t-steps, @state  5, eps=0.90(   233), loss=0.2134
# Episode:  15/2000 --  failed   (wins= 0/ 1) in  14 t-steps, @state 12, eps=0.68(   247), loss=0.2321
# Episode:  16/2000 --  failed   (wins= 0/ 1) in   3 t-steps, @state  5, eps=0.64(   250), loss=0.2384
# Episode:  17/2000 --  failed   (wins= 0/ 1) in   5 t-steps, @state  5, eps=0.58(   255), loss=0.2071
# Episode:  18/2000 --  failed   (wins= 0/ 1) in  55 t-steps, @state  5, eps=0.19(   310), loss=0.1019
# Episode:  19/2000 --  failed   (wins= 0/ 1) in   7 t-steps, @state 12, eps=0.17(   317), loss=0.1763
# Episode:  20/2000 --  failed   (wins= 0/ 1) in 100 t-steps, @state  0, eps=0.02(   417), loss=0.4098
# Episode:  21/2000 --  failed   (wins= 0/ 1) in  44 t-steps, @state  5, eps=0.90(   461), loss=0.3164
# Episode:  22/2000 --  failed   (wins= 0/ 1) in   5 t-steps, @state  5, eps=0.82(   466), loss=0.1570
# Episode:  23/2000 --  failed   (wins= 0/ 1) in  12 t-steps, @state  5, eps=0.64(   478), loss=0.0383
# Episode:  24/2000 --  failed   (wins= 0/ 1) in  11 t-steps, @state  5, eps=0.51(   489), loss=0.0060
# Episode:  25/2000 --  failed   (wins= 0/ 1) in   4 t-steps, @state  5, eps=0.47(   493), loss=0.0449
# Episode:  26/2000 --  failed   (wins= 0/ 1) in   4 t-steps, @state 12, eps=0.44(   497), loss=0.0251
# Episode:  27/2000 --  failed   (wins= 0/ 1) in   3 t-steps, @state 12, eps=0.41(   500), loss=0.0332
# Episode:  28/2000 --  failed   (wins= 0/ 1) in   3 t-steps, @state  5, eps=0.39(   503), loss=0.0119
# Episode:  29/2000 --  failed   (wins= 0/ 1) in   4 t-steps, @state 12, eps=0.36(   507), loss=0.0117
# Episode:  30/2000 --  failed   (wins= 0/ 1) in   6 t-steps, @state 12, eps=0.32(   513), loss=0.0106
# Episode:  31/2000 --  failed   (wins= 0/ 1) in   3 t-steps, @state 12, eps=0.30(   516), loss=0.0108
# Episode:  32/2000 --  failed   (wins= 0/ 1) in   2 t-steps, @state  5, eps=0.29(   518), loss=0.0038
# Episode:  33/2000 -- *success* (wins= 1/ 1) in   6 t-steps, @state 15, eps=0.25(   524), loss=0.0037
# Episode:  34/2000 -- *success* (wins= 2/ 2) in   8 t-steps, @state 15, eps=0.22(   532), loss=0.0055
# Episode:  35/2000 -- *success* (wins= 3/ 3) in   6 t-steps, @state 15, eps=0.19(   538), loss=0.0089
# Episode:  36/2000 -- *success* (wins= 4/ 4) in   7 t-steps, @state 15, eps=0.17(   545), loss=0.0054
# Episode:  37/2000 -- *success* (wins= 5/ 5) in   6 t-steps, @state 15, eps=0.15(   551), loss=0.0018
# Episode:  38/2000 -- *success* (wins= 6/ 6) in   8 t-steps, @state 15, eps=0.12(   559), loss=0.0000
# Episode:  39/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.12(   562), loss=0.0000
# Episode:  40/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.11(   565), loss=0.0008
# Episode:  41/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.10(   568), loss=0.0081
# Episode:  42/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.10(   571), loss=0.0046
# Episode:  43/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.09(   574), loss=0.0000
# Episode:  44/2000 --  failed   (wins= 0/ 6) in   5 t-steps, @state 12, eps=0.08(   579), loss=0.0000
# Episode:  45/2000 --  failed   (wins= 0/ 6) in   4 t-steps, @state 12, eps=0.08(   583), loss=0.0010
# Episode:  46/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.07(   586), loss=0.0024
# Episode:  47/2000 --  failed   (wins= 0/ 6) in   5 t-steps, @state 12, eps=0.07(   591), loss=0.0000
# Episode:  48/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.06(   594), loss=0.0000
# Episode:  49/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.06(   597), loss=0.0000
# Episode:  50/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.05(   600), loss=0.0024
# Episode:  51/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.05(   603), loss=0.0000
# Episode:  52/2000 --  failed   (wins= 0/ 6) in   3 t-steps, @state 12, eps=0.05(   606), loss=0.0000
# Episode:  53/2000 -- *success* (wins= 1/ 6) in   6 t-steps, @state 15, eps=0.04(   612), loss=0.0012
# Episode:  54/2000 -- *success* (wins= 2/ 6) in   6 t-steps, @state 15, eps=0.04(   618), loss=0.0022
# Episode:  55/2000 -- *success* (wins= 3/ 6) in   6 t-steps, @state 15, eps=0.03(   624), loss=0.0045
# Episode:  56/2000 -- *success* (wins= 4/ 6) in   6 t-steps, @state 15, eps=0.03(   630), loss=0.0007
# Episode:  57/2000 -- *success* (wins= 5/ 6) in   6 t-steps, @state 15, eps=0.03(   636), loss=0.0010
# Episode:  58/2000 -- *success* (wins= 6/ 6) in   6 t-steps, @state 15, eps=0.02(   642), loss=0.0000
# Episode:  59/2000 -- *success* (wins= 7/ 7) in   6 t-steps, @state 15, eps=0.02(   648), loss=0.0036
# Episode:  60/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state  5, eps=0.02(   652), loss=0.0000
# Episode:  61/2000 --  failed   (wins= 0/ 7) in  45 t-steps, @state 11, eps=0.77(   697), loss=0.0000
# Episode:  62/2000 --  failed   (wins= 0/ 7) in  10 t-steps, @state  5, eps=0.63(   707), loss=0.0000
# Episode:  63/2000 -- *success* (wins= 1/ 7) in  11 t-steps, @state 15, eps=0.50(   718), loss=0.0080
# Episode:  64/2000 --  failed   (wins= 0/ 7) in   2 t-steps, @state  5, eps=0.48(   720), loss=0.0177
# Episode:  65/2000 --  failed   (wins= 0/ 7) in   8 t-steps, @state  5, eps=0.41(   728), loss=0.0039
# Episode:  66/2000 -- *success* (wins= 1/ 7) in  26 t-steps, @state 15, eps=0.24(   754), loss=0.0200
# Episode:  67/2000 -- *success* (wins= 2/ 7) in   6 t-steps, @state 15, eps=0.22(   760), loss=0.0065
# Episode:  68/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state  5, eps=0.20(   764), loss=0.0063
# Episode:  69/2000 -- *success* (wins= 1/ 7) in   6 t-steps, @state 15, eps=0.18(   770), loss=0.0101
# Episode:  70/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state 12, eps=0.16(   774), loss=0.0061
# Episode:  71/2000 -- *success* (wins= 1/ 7) in   7 t-steps, @state 15, eps=0.14(   781), loss=0.0026
# Episode:  72/2000 -- *success* (wins= 2/ 7) in   6 t-steps, @state 15, eps=0.12(   787), loss=0.0177
# Episode:  73/2000 -- *success* (wins= 3/ 7) in   7 t-steps, @state 15, eps=0.11(   794), loss=0.0299
# Episode:  74/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state 12, eps=0.10(   798), loss=0.0185
# Episode:  75/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.09(   801), loss=0.0269
# Episode:  76/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.09(   804), loss=0.0233
# Episode:  77/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.08(   807), loss=0.0136
# Episode:  78/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.08(   810), loss=0.0074
# Episode:  79/2000 --  failed   (wins= 0/ 7) in   2 t-steps, @state  5, eps=0.08(   812), loss=0.0151
# Episode:  80/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.07(   815), loss=0.0444
# Episode:  81/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.07(   818), loss=0.0081
# Episode:  82/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.06(   821), loss=0.0185
# Episode:  83/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.06(   824), loss=0.0078
# Episode:  84/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.06(   827), loss=0.0071
# Episode:  85/2000 --  failed   (wins= 0/ 7) in   5 t-steps, @state 12, eps=0.05(   832), loss=0.0062
# Episode:  86/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.05(   835), loss=0.0200
# Episode:  87/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.04(   838), loss=0.0125
# Episode:  88/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.04(   841), loss=0.0123
# Episode:  89/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.04(   844), loss=0.0123
# Episode:  90/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.04(   847), loss=0.0164
# Episode:  91/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.03(   850), loss=0.0121
# Episode:  92/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.03(   853), loss=0.0127
# Episode:  93/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.03(   856), loss=0.0184
# Episode:  94/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.03(   859), loss=0.0106
# Episode:  95/2000 --  failed   (wins= 0/ 7) in   2 t-steps, @state  5, eps=0.03(   861), loss=0.0121
# Episode:  96/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.03(   864), loss=0.0287
# Episode:  97/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   867), loss=0.0187
# Episode:  98/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   870), loss=0.0253
# Episode:  99/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   873), loss=0.0063
# Episode: 100/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   876), loss=0.0055
# Episode: 101/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   879), loss=0.0249
# Episode: 102/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   882), loss=0.0245
# Episode: 103/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   885), loss=0.0123
# Episode: 104/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   888), loss=0.0198
# Episode: 105/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.02(   891), loss=0.0188
# Episode: 106/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   894), loss=0.0056
# Episode: 107/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   897), loss=0.0174
# Episode: 108/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   900), loss=0.0122
# Episode: 109/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   903), loss=0.0056
# Episode: 110/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   906), loss=0.0243
# Episode: 111/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.01(   909), loss=0.0118
# Episode: 112/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state  5, eps=0.98(   913), loss=0.0176
# Episode: 113/2000 --  failed   (wins= 0/ 7) in   9 t-steps, @state 11, eps=0.82(   922), loss=0.0068
# Episode: 114/2000 --  failed   (wins= 0/ 7) in   4 t-steps, @state  5, eps=0
2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.07(  1731), loss=0.0101
# Episode: 340/2000 --  failed   (wins= 0/ 7) in   3 t-steps, @state 12, eps=0.06(  1734), loss=0.0095
# Episode: 341/2000 -- *success* (wins= 1/ 7) in   6 t-steps, @state 15, eps=0.05(  1740), loss=0.0060
# Episode: 342/2000 -- *success* (wins= 2/ 7) in   6 t-steps, @state 15, eps=0.05(  1746), loss=0.0015
# Episode: 343/2000 -- *success* (wins= 3/ 7) in   6 t-steps, @state 15, eps=0.04(  1752), loss=0.0086
# Episode: 344/2000 -- *success* (wins= 4/ 7) in   6 t-steps, @state 15, eps=0.04(  1758), loss=0.0136
# Episode: 345/2000 -- *success* (wins= 5/ 7) in   6 t-steps, @state 15, eps=0.03(  1764), loss=0.0144
# Episode: 346/2000 -- *success* (wins= 6/ 7) in   6 t-steps, @state 15, eps=0.03(  1770), loss=0.0204
# Episode: 347/2000 -- *success* (wins= 7/ 7) in   6 t-steps, @state 15, eps=0.03(  1776), loss=0.0071
# Episode: 348/2000 -- *success* (wins= 8/ 8) in   6 t-steps, @state 15, eps=0.02(  1782), loss=0.0072
# Episode: 349/2000 -- *success* (wins= 9/ 9) in   6 t-steps, @state 15, eps=0.02(  1788), loss=0.0080
# Episode: 350/2000 -- *success* (wins=10/10) in   6 t-steps, @state 15, eps=0.02(  1794), loss=0.0081
# Episode: 351/2000 -- *success* (wins=11/11) in   6 t-steps, @state 15, eps=0.02(  1800), loss=0.0078
# Episode: 352/2000 -- *success* (wins=12/12) in   6 t-steps, @state 15, eps=0.01(  1806), loss=0.0081
# Episode: 353/2000 -- *success* (wins=13/13) in   6 t-steps, @state 15, eps=0.01(  1812), loss=0.0139
# Episode: 354/2000 -- *success* (wins=14/14) in   6 t-steps, @state 15, eps=0.01(  1818), loss=0.0056
# Episode: 355/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.01(  1821), loss=0.0154
# Episode: 356/2000 --  failed   (wins= 0/14) in   9 t-steps, @state 12, eps=0.89(  1830), loss=0.0079
# Episode: 357/2000 --  failed   (wins= 0/14) in   6 t-steps, @state 12, eps=0.78(  1836), loss=0.0115
# Episode: 358/2000 --  failed   (wins= 0/14) in  10 t-steps, @state 12, eps=0.64(  1846), loss=0.0168
# Episode: 359/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.59(  1850), loss=0.0063
# Episode: 360/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.55(  1854), loss=0.0189
# Episode: 361/2000 --  failed   (wins= 0/14) in  18 t-steps, @state  5, eps=0.38(  1872), loss=0.0000
# Episode: 362/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.36(  1875), loss=0.0187
# Episode: 363/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.34(  1878), loss=0.0112
# Episode: 364/2000 --  failed   (wins= 0/14) in   4 t-steps, @state 12, eps=0.31(  1882), loss=0.0185
# Episode: 365/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 12, eps=0.28(  1887), loss=0.0092
# Episode: 366/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 12, eps=0.25(  1892), loss=0.0267
# Episode: 367/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.24(  1895), loss=0.0045
# Episode: 368/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.22(  1898), loss=0.0119
# Episode: 369/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.21(  1901), loss=0.0178
# Episode: 370/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 12, eps=0.19(  1906), loss=0.0093
# Episode: 371/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.18(  1909), loss=0.0089
# Episode: 372/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.17(  1912), loss=0.0166
# Episode: 373/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.16(  1915), loss=0.0043
# Episode: 374/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 12, eps=0.14(  1920), loss=0.0287
# Episode: 375/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.14(  1923), loss=0.0000
# Episode: 376/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0.13(  1926), loss=0.0080
# Episode: 377/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=0
2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.33(  2107), loss=0.0660
# Episode: 419/2000 -- *success* (wins= 1/14) in  15 t-steps, @state 15, eps=0.24(  2122), loss=0.0590
# Episode: 420/2000 -- *success* (wins= 2/14) in  10 t-steps, @state 15, eps=0.20(  2132), loss=0.0152
# Episode: 421/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=0.18(  2138), loss=0.0188
# Episode: 422/2000 -- *success* (wins= 4/14) in   8 t-steps, @state 15, eps=0.15(  2146), loss=0.0255
# Episode: 423/2000 -- *success* (wins= 5/14) in   7 t-steps, @state 15, eps=0.13(  2153), loss=0.0271
# Episode: 424/2000 -- *success* (wins= 6/14) in   6 t-steps, @state 15, eps=0.12(  2159), loss=0.0202
# Episode: 425/2000 -- *success* (wins= 7/14) in   6 t-steps, @state 15, eps=0.10(  2165), loss=0.0399
# Episode: 426/2000 -- *success* (wins= 8/14) in   6 t-steps, @state 15, eps=0.09(  2171), loss=0.0419
# Episode: 427/2000 -- *success* (wins= 9/14) in   8 t-steps, @state 15, eps=0.08(  2179), loss=0.0517
# Episode: 428/2000 -- *success* (wins=10/14) in   6 t-steps, @state 15, eps=0.07(  2185), loss=0.0214
# Episode: 429/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.06(  2189), loss=0.0357
# Episode: 430/2000 -- *success* (wins= 1/14) in   6 t-steps, @state 15, eps=0.06(  2195), loss=0.0637
# Episode: 431/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.05(  2201), loss=0.0228
# Episode: 432/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=0.04(  2207), loss=0.0464
# Episode: 433/2000 -- *success* (wins= 4/14) in   6 t-steps, @state 15, eps=0.04(  2213), loss=0.0275
# Episode: 434/2000 -- *success* (wins= 5/14) in   6 t-steps, @state 15, eps=0.03(  2219), loss=0.0398
# Episode: 435/2000 -- *success* (wins= 6/14) in   6 t-steps, @state 15, eps=0.03(  2225), loss=0.0176
# Episode: 436/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 11, eps=0.03(  2230), loss=0.0168
# Episode: 437/2000 -- *success* (wins= 1/14) in   6 t-steps, @state 15, eps=0.02(  2236), loss=0.0647
# Episode: 438/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.02(  2242), loss=0.1097
# Episode: 439/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=0.02(  2248), loss=0.0239
# Episode: 440/2000 -- *success* (wins= 4/14) in   6 t-steps, @state 15, eps=0.02(  2254), loss=0.0374
# Episode: 441/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 11, eps=0.02(  2259), loss=0.0182
# Episode: 442/2000 -- *success* (wins= 1/14) in   6 t-steps, @state 15, eps=0.01(  2265), loss=0.0246
# Episode: 443/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.01(  2271), loss=0.0414
# Episode: 444/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=0.01(  2277), loss=0.0421
# Episode: 445/2000 --  failed   (wins= 0/14) in   3 t-steps, @state 12, eps=1.00(  2280), loss=0.0426
# Episode: 446/2000 --  failed   (wins= 0/14) in   6 t-steps, @state  5, eps=0.89(  2286), loss=0.0000
# Episode: 447/2000 --  failed   (wins= 0/14) in   5 t-steps, @state  5, eps=0.80(  2291), loss=0.0100
# Episode: 448/2000 --  failed   (wins= 0/14) in   6 t-steps, @state  5, eps=0.71(  2297), loss=0.0240
# Episode: 449/2000 --  failed   (wins= 0/14) in   2 t-steps, @state  5, eps=0.68(  2299), loss=0.0421
# Episode: 450/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.63(  2303), loss=0.0016
# Episode: 451/2000 --  failed   (wins= 0/14) in   7 t-steps, @state 11, eps=0.55(  2310), loss=0.0362
# Episode: 452/2000 --  failed   (wins= 0/14) in   7 t-steps, @state 12, eps=0.47(  2317), loss=0.0480
# Episode: 453/2000 -- *success* (wins= 1/14) in   8 t-steps, @state 15, eps=0.40(  2325), loss=0.0116
# Episode: 454/2000 --  failed   (wins= 0/14) in   5 t-steps, @state 12, eps=0.36(  2330), loss=0.0261
# Episode: 455/2000 -- *success* (wins= 1/14) in   6 t-steps, @state 15, eps=0.32(  2336), loss=0.0443
# Episode: 456/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.29(  2342), loss=0.0313
# Episode: 457/2000 -- *success* (wins= 3/14) in   7 t-steps, @state 15, eps=0.25(  2349), loss=0.0228
# Episode: 458/2000 --  failed   (wins= 0/14) in   5 t-steps, @state  5, eps=0.22(  2354), loss=0.0457
# Episode: 459/2000 -- *success* (wins= 1/14) in   8 t-steps, @state 15, eps=0.19(  2362), loss=0.0461
# Episode: 460/2000 -- *success* (wins= 2/14) in   8 t-steps, @state 15, eps=0.16(  2370), loss=0.0490
# Episode: 461/2000 -- *success* (wins= 3/14) in  28 t-steps, @state 15, eps=0.09(  2398), loss=0.0169
# Episode: 462/2000 -- *success* (wins= 4/14) in   6 t-steps, @state 15, eps=0.08(  2404), loss=0.0463
# Episode: 463/2000 -- *success* (wins= 5/14) in   6 t-steps, @state 15, eps=0.07(  2410), loss=0.0388
# Episode: 464/2000 --  failed   (wins= 0/14) in  12 t-steps, @state  5, eps=0.06(  2422), loss=0.0175
# Episode: 465/2000 -- *success* (wins= 1/14) in   6 t-steps, @state 15, eps=0.05(  2428), loss=0.0515
# Episode: 466/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.04(  2434), loss=0.0178
# Episode: 467/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=0.04(  2440), loss=0.0307
# Episode: 468/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.04(  2444), loss=0.0599
# Episode: 469/2000 -- *success* (wins= 1/14) in  52 t-steps, @state 15, eps=0.01(  2496), loss=0.0435
# Episode: 470/2000 -- *success* (wins= 2/14) in   6 t-steps, @state 15, eps=0.01(  2502), loss=0.0519
# Episode: 471/2000 -- *success* (wins= 3/14) in   6 t-steps, @state 15, eps=1.00(  2508), loss=0.0432
# Episode: 472/2000 --  failed   (wins= 0/14) in   4 t-steps, @state  5, eps=0.92(  2512), loss=0.0335
# Episode: 473/2000 --  failed   (wins= 0/14) in   3 t-steps, @state  5, eps=0.87(  2515), loss=0.0361
# Episode: 474/2000 --  failed   (wins= 0/14) in   8 t-steps, @state  5, eps=0.74(  2523), loss=0.0285
# Episode: 475/2000 -- *success* (wins= 1/14) in  12 t-steps, @state 15, eps=0.58(  2535), loss=0.0161
# ...
# Episode:1843/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.24( 11698), loss=0.0761
# Episode:1844/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=0.22( 11703), loss=0.0699
# Episode:1845/2000 -- *success* (wins= 1/30) in   8 t-steps, @state 15, eps=0.19( 11711), loss=0.0970
# Episode:1846/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.17( 11717), loss=0.0836
# Episode:1847/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.15( 11723), loss=0.1078
# Episode:1848/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.13( 11729), loss=0.0616
# Episode:1849/2000 -- *success* (wins= 5/30) in   9 t-steps, @state 15, eps=0.11( 11738), loss=0.1077
# Episode:1850/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.10( 11744), loss=0.0964
# Episode:1851/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.09( 11746), loss=0.0520
# Episode:1852/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.08( 11752), loss=0.0427
# Episode:1853/2000 -- *success* (wins= 2/30) in   7 t-steps, @state 15, eps=0.07( 11759), loss=0.0460
# Episode:1854/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.07( 11761), loss=0.0639
# Episode:1855/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.06( 11767), loss=0.0418
# Episode:1856/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.05( 11773), loss=0.1000
# Episode:1857/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.05( 11779), loss=0.0720
# Episode:1858/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.04( 11785), loss=0.0950
# Episode:1859/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.04( 11791), loss=0.0610
# Episode:1860/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.03( 11797), loss=0.1021
# Episode:1861/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.03( 11803), loss=0.0993
# Episode:1862/2000 -- *success* (wins= 8/30) in   6 t-steps, @state 15, eps=0.03( 11809), loss=0.0464
# Episode:1863/2000 -- *success* (wins= 9/30) in   6 t-steps, @state 15, eps=0.02( 11815), loss=0.0812
# Episode:1864/2000 -- *success* (wins=10/30) in   6 t-steps, @state 15, eps=0.02( 11821), loss=0.0699
# Episode:1865/2000 -- *success* (wins=11/30) in   6 t-steps, @state 15, eps=0.02( 11827), loss=0.0874
# Episode:1866/2000 -- *success* (wins=12/30) in   6 t-steps, @state 15, eps=0.02( 11833), loss=0.0808
# Episode:1867/2000 -- *success* (wins=13/30) in   6 t-steps, @state 15, eps=0.01( 11839), loss=0.0890
# Episode:1868/2000 -- *success* (wins=14/30) in   6 t-steps, @state 15, eps=0.01( 11845), loss=0.0769
# Episode:1869/2000 -- *success* (wins=15/30) in   6 t-steps, @state 15, eps=0.01( 11851), loss=0.1319
# Episode:1870/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=1.00( 11856), loss=0.0583
# Episode:1871/2000 --  failed   (wins= 0/30) in  12 t-steps, @state  7, eps=0.78( 11868), loss=0.0802
# Episode:1872/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.70( 11874), loss=0.0668
# Episode:1873/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.67( 11876), loss=0.0592
# Episode:1874/2000 -- *success* (wins= 1/30) in   9 t-steps, @state 15, eps=0.56( 11885), loss=0.0824
# Episode:1875/2000 -- *success* (wins= 2/30) in  13 t-steps, @state 15, eps=0.43( 11898), loss=0.0462
# Episode:1876/2000 -- *success* (wins= 3/30) in  11 t-steps, @state 15, eps=0.34( 11909), loss=0.1094
# Episode:1877/2000 -- *success* (wins= 4/30) in  11 t-steps, @state 15, eps=0.27( 11920), loss=0.0748
# Episode:1878/2000 -- *success* (wins= 5/30) in   8 t-steps, @state 15, eps=0.23( 11928), loss=0.0933
# Episode:1879/2000 -- *success* (wins= 6/30) in  12 t-steps, @state 15, eps=0.18( 11940), loss=0.0644
# Episode:1880/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.17( 11944), loss=0.1085
# Episode:1881/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.15( 11950), loss=0.0837
# Episode:1882/2000 -- *success* (wins= 2/30) in   9 t-steps, @state 15, eps=0.12( 11959), loss=0.0823
# Episode:1883/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.11( 11965), loss=0.0731
# Episode:1884/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.10( 11971), loss=0.0487
# Episode:1885/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.09( 11977), loss=0.0673
# Episode:1886/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.08( 11983), loss=0.1006
# Episode:1887/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.07( 11989), loss=0.1061
# Episode:1888/2000 -- *success* (wins= 8/30) in   6 t-steps, @state 15, eps=0.06( 11995), loss=0.0805
# Episode:1889/2000 -- *success* (wins= 9/30) in   6 t-steps, @state 15, eps=0.05( 12001), loss=0.1124
# Episode:1890/2000 -- *success* (wins=10/30) in   6 t-steps, @state 15, eps=0.05( 12007), loss=0.0855
# Episode:1891/2000 -- *success* (wins=11/30) in   6 t-steps, @state 15, eps=0.04( 12013), loss=0.0803
# Episode:1892/2000 -- *success* (wins=12/30) in   6 t-steps, @state 15, eps=0.04( 12019), loss=0.1029
# Episode:1893/2000 -- *success* (wins=13/30) in   6 t-steps, @state 15, eps=0.03( 12025), loss=0.0503
# Episode:1894/2000 -- *success* (wins=14/30) in   7 t-steps, @state 15, eps=0.03( 12032), loss=0.0662
# Episode:1895/2000 -- *success* (wins=15/30) in   6 t-steps, @state 15, eps=0.03( 12038), loss=0.0864
# Episode:1896/2000 -- *success* (wins=16/30) in   6 t-steps, @state 15, eps=0.02( 12044), loss=0.0947
# Episode:1897/2000 -- *success* (wins=17/30) in   6 t-steps, @state 15, eps=0.02( 12050), loss=0.0687
# Episode:1898/2000 -- *success* (wins=18/30) in   6 t-steps, @state 15, eps=0.02( 12056), loss=0.0789
# Episode:1899/2000 -- *success* (wins=19/30) in   6 t-steps, @state 15, eps=0.02( 12062), loss=0.0618
# Episode:1900/2000 -- *success* (wins=20/30) in   6 t-steps, @state 15, eps=0.01( 12068), loss=0.0762
# Episode:1901/2000 -- *success* (wins=21/30) in   6 t-steps, @state 15, eps=0.01( 12074), loss=0.0628
# Episode:1902/2000 -- *success* (wins=22/30) in   6 t-steps, @state 15, eps=0.01( 12080), loss=0.0853
# Episode:1903/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 12, eps=0.98( 12085), loss=0.0268
# Episode:1904/2000 --  failed   (wins= 0/30) in   6 t-steps, @state  5, eps=0.87( 12091), loss=0.0814
# Episode:1905/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=0.78( 12096), loss=0.0902
# Episode:1906/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.72( 12100), loss=0.0790
# Episode:1907/2000 --  failed   (wins= 0/30) in  12 t-steps, @state  5, eps=0.57( 12112), loss=0.0390
# Episode:1908/2000 --  failed   (wins= 0/30) in   3 t-steps, @state 12, eps=0.53( 12115), loss=0.0671
# Episode:1909/2000 --  failed   (wins= 0/30) in   8 t-steps, @state  5, eps=0.45( 12123), loss=0.0991
# Episode:1910/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.40( 12129), loss=0.0781
# Episode:1911/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=0.36( 12134), loss=0.0798
# Episode:1912/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.32( 12140), loss=0.1331
# Episode:1913/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.29( 12146), loss=0.0840
# Episode:1914/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.27( 12148), loss=0.1195
# Episode:1915/2000 --  failed   (wins= 0/30) in   7 t-steps, @state 11, eps=0.24( 12155), loss=0.0760
# Episode:1916/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.21( 12161), loss=0.0912
# Episode:1917/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.19( 12165), loss=0.0704
# Episode:1918/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.17( 12171), loss=0.0477
# Episode:1919/2000 --  failed   (wins= 0/30) in   3 t-steps, @state 12, eps=0.16( 12174), loss=0.0712
# Episode:1920/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.14( 12180), loss=0.0725
# Episode:1921/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.13( 12186), loss=0.0730
# Episode:1922/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.11( 12192), loss=0.1028
# Episode:1923/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.10( 12198), loss=0.0359
# Episode:1924/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.09( 12204), loss=0.0649
# Episode:1925/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.08( 12210), loss=0.0898
# Episode:1926/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=0.07( 12215), loss=0.0720
# Episode:1927/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.06( 12221), loss=0.0885
# Episode:1928/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.06( 12227), loss=0.0815
# Episode:1929/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.05( 12233), loss=0.0771
# Episode:1930/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.04( 12239), loss=0.0672
# Episode:1931/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.04( 12245), loss=0.0883
# Episode:1932/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.03( 12251), loss=0.0691
# Episode:1933/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.03( 12257), loss=0.0827
# Episode:1934/2000 -- *success* (wins= 8/30) in   6 t-steps, @state 15, eps=0.03( 12263), loss=0.0617
# Episode:1935/2000 -- *success* (wins= 9/30) in   6 t-steps, @state 15, eps=0.02( 12269), loss=0.0873
# Episode:1936/2000 -- *success* (wins=10/30) in   7 t-steps, @state 15, eps=0.02( 12276), loss=0.0457
# Episode:1937/2000 -- *success* (wins=11/30) in   6 t-steps, @state 15, eps=0.02( 12282), loss=0.0697
# Episode:1938/2000 -- *success* (wins=12/30) in   6 t-steps, @state 15, eps=0.02( 12288), loss=0.0388
# Episode:1939/2000 -- *success* (wins=13/30) in   6 t-steps, @state 15, eps=0.01( 12294), loss=0.0602
# Episode:1940/2000 -- *success* (wins=14/30) in   6 t-steps, @state 15, eps=0.01( 12300), loss=0.1051
# Episode:1941/2000 -- *success* (wins=15/30) in   6 t-steps, @state 15, eps=0.01( 12306), loss=0.0619
# Episode:1942/2000 --  failed   (wins= 0/30) in  13 t-steps, @state  5, eps=0.87( 12319), loss=0.0467
# Episode:1943/2000 --  failed   (wins= 0/30) in  17 t-steps, @state 12, eps=0.62( 12336), loss=0.0794
# Episode:1944/2000 --  failed   (wins= 0/30) in   3 t-steps, @state  5, eps=0.58( 12339), loss=0.1093
# Episode:1945/2000 --  failed   (wins= 0/30) in   8 t-steps, @state  7, eps=0.49( 12347), loss=0.0928
# Episode:1946/2000 --  failed   (wins= 0/30) in   4 t-steps, @state 12, eps=0.45( 12351), loss=0.1034
# Episode:1947/2000 --  failed   (wins= 0/30) in   5 t-steps, @state  5, eps=0.41( 12356), loss=0.0586
# Episode:1948/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.36( 12362), loss=0.0784
# Episode:1949/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.35( 12364), loss=0.0804
# Episode:1950/2000 -- *success* (wins= 1/30) in   7 t-steps, @state 15, eps=0.30( 12371), loss=0.0612
# Episode:1951/2000 -- *success* (wins= 2/30) in   9 t-steps, @state 15, eps=0.25( 12380), loss=0.0740
# Episode:1952/2000 -- *success* (wins= 3/30) in  13 t-steps, @state 15, eps=0.19( 12393), loss=0.0887
# Episode:1953/2000 -- *success* (wins= 4/30) in   7 t-steps, @state 15, eps=0.17( 12400), loss=0.0758
# Episode:1954/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.16( 12404), loss=0.0650
# Episode:1955/2000 -- *success* (wins= 1/30) in   8 t-steps, @state 15, eps=0.13( 12412), loss=0.0469
# Episode:1956/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.12( 12418), loss=0.0891
# Episode:1957/2000 -- *success* (wins= 3/30) in   8 t-steps, @state 15, eps=0.10( 12426), loss=0.0987
# Episode:1958/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.09( 12432), loss=0.0971
# Episode:1959/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.08( 12438), loss=0.0933
# Episode:1960/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.07( 12444), loss=0.0738
# Episode:1961/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.06( 12450), loss=0.0382
# Episode:1962/2000 -- *success* (wins= 8/30) in   7 t-steps, @state 15, eps=0.05( 12457), loss=0.0706
# Episode:1963/2000 --  failed   (wins= 0/30) in   7 t-steps, @state 12, eps=0.05( 12464), loss=0.0598
# Episode:1964/2000 -- *success* (wins= 1/30) in   6 t-steps, @state 15, eps=0.04( 12470), loss=0.0734
# Episode:1965/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.04( 12476), loss=0.0665
# Episode:1966/2000 -- *success* (wins= 3/30) in   6 t-steps, @state 15, eps=0.03( 12482), loss=0.0770
# Episode:1967/2000 -- *success* (wins= 4/30) in   6 t-steps, @state 15, eps=0.03( 12488), loss=0.1186
# Episode:1968/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.03( 12494), loss=0.1147
# Episode:1969/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.02( 12500), loss=0.0595
# Episode:1970/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.02( 12506), loss=0.0466
# Episode:1971/2000 -- *success* (wins= 8/30) in   6 t-steps, @state 15, eps=0.02( 12512), loss=0.0705
# Episode:1972/2000 -- *success* (wins= 9/30) in   6 t-steps, @state 15, eps=0.02( 12518), loss=0.0843
# Episode:1973/2000 -- *success* (wins=10/30) in   6 t-steps, @state 15, eps=0.01( 12524), loss=0.0923
# Episode:1974/2000 -- *success* (wins=11/30) in   6 t-steps, @state 15, eps=0.01( 12530), loss=0.0705
# Episode:1975/2000 -- *success* (wins=12/30) in   6 t-steps, @state 15, eps=0.01( 12536), loss=0.0688
# Episode:1976/2000 --  failed   (wins= 0/30) in   5 t-steps, @state 11, eps=0.98( 12541), loss=0.0856
# Episode:1977/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.90( 12545), loss=0.0844
# Episode:1978/2000 --  failed   (wins= 0/30) in   8 t-steps, @state 12, eps=0.77( 12553), loss=0.1348
# Episode:1979/2000 --  failed   (wins= 0/30) in   5 t-steps, @state  5, eps=0.70( 12558), loss=0.0919
# Episode:1980/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.67( 12560), loss=0.0486
# Episode:1981/2000 -- *success* (wins= 1/30) in   9 t-steps, @state 15, eps=0.56( 12569), loss=0.0859
# Episode:1982/2000 --  failed   (wins= 0/30) in   2 t-steps, @state  5, eps=0.53( 12571), loss=0.0605
# Episode:1983/2000 -- *success* (wins= 1/30) in  10 t-steps, @state 15, eps=0.44( 12581), loss=0.0723
# Episode:1984/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.39( 12587), loss=0.0751
# Episode:1985/2000 -- *success* (wins= 3/30) in   9 t-steps, @state 15, eps=0.32( 12596), loss=0.0290
# Episode:1986/2000 --  failed   (wins= 0/30) in   9 t-steps, @state 12, eps=0.27( 12605), loss=0.1284
# Episode:1987/2000 -- *success* (wins= 1/30) in   7 t-steps, @state 15, eps=0.23( 12612), loss=0.0675
# Episode:1988/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.22( 12616), loss=0.0983
# Episode:1989/2000 --  failed   (wins= 0/30) in   4 t-steps, @state  5, eps=0.20( 12620), loss=0.0451
# Episode:1990/2000 -- *success* (wins= 1/30) in   7 t-steps, @state 15, eps=0.17( 12627), loss=0.0674
# Episode:1991/2000 -- *success* (wins= 2/30) in   6 t-steps, @state 15, eps=0.15( 12633), loss=0.0767
# Episode:1992/2000 -- *success* (wins= 3/30) in   7 t-steps, @state 15, eps=0.13( 12640), loss=0.1256
# Episode:1993/2000 -- *success* (wins= 4/30) in   8 t-steps, @state 15, eps=0.11( 12648), loss=0.0842
# Episode:1994/2000 -- *success* (wins= 5/30) in   6 t-steps, @state 15, eps=0.10( 12654), loss=0.0808
# Episode:1995/2000 -- *success* (wins= 6/30) in   6 t-steps, @state 15, eps=0.09( 12660), loss=0.0590
# Episode:1996/2000 -- *success* (wins= 7/30) in   6 t-steps, @state 15, eps=0.08( 12666), loss=0.0627
# Episode:1997/2000 -- *success* (wins= 8/30) in   7 t-steps, @state 15, eps=0.07( 12673), loss=0.1076
# Episode:1998/2000 -- *success* (wins= 9/30) in   6 t-steps, @state 15, eps=0.06( 12679), loss=0.0630
# Episode:1999/2000 -- *success* (wins=10/30) in   6 t-steps, @state 15, eps=0.05( 12685), loss=0.0545
# Episode:2000/2000 -- *success* (wins=11/30) in   6 t-steps, @state 15, eps=0.05( 12691), loss=0.0835

# %%
# Validate on a series of several consecutive runs
env = gym.make('FrozenLake-v0', is_slippery=True)
wins = 0
max_wins = 0
for i in range(10):
  state = env.reset()
  done = False
  for ind_step in count():
    #env.render()                    # Uncomment to see game running
    state = to_categorical(state, in_shape).reshape(-1, in_shape)
    action = net_policy.predict(state).argmax()
    state, reward, done, info = env.step(action)
    if done:
        break
  if reward == 1:
    #print("Win!")
    wins += 1
  else:
    #print("Lose!")
    wins = 0
  max_wins = max(max_wins, wins)
env.close()

print('Max number of consecutive wins: {}'.format(max_wins))
# Out:
# Max number of consecutive wins: 0

# %%
# See output for one single episode
env = gym.make('FrozenLake-v0', is_slippery=True)
state = env.reset()
tot_r, done = 0, False
for ind_step in count():
    env.render()                    # Uncomment to see game running
    state = to_categorical(state, in_shape).reshape(-1, in_shape)
    action = net_policy.predict(state).argmax()
    state, reward, done, info = env.step(action)
    tot_r += reward
    if done:
        break
env.render()        
env.close()
print('Game ended! Total reward: {}'.format(tot_r))
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Game ended! Total reward: 0.0

# %%
# Save trained model for future use
#net_policy.save("net_policy.h5")
