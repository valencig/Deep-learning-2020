# %%
# Source: https://towardsdatascience.com/reinforcement-learning-with-ohttps://github.com/openai/gym/wiki/Environmentspenai-d445c2c687d2
#
# https://gym.openai.com/envs/#classic_control
# https://github.com/openai/gym/wiki/Environments

# conda install -n py37 gym[atari] -c conda-forge
# conda install -n py37 gym[all] -c conda-forge
# conda install -n py37 atari_py -c conda-forge
# conda install -n py37 pybox2d -c conda-forge

# Acrobot-v1
# CartPole-v0
# MountainCar-v0
# MountainCarContinuous-v0

# Pong-v0
# MsPacman-v0

# CarRacing-v0

# FrozenLake8x8-v0

# %% [markdown]
# # DE AQUI

# %%
# https://deeplizard.com/learn/video/a-SnJtmBtyA
# https://www.youtube.com/watch?v=nyjbcRQ-uQ8&list=PLZbbT5o_s2xoWNVdDudn51XM8lOuZ_Njv

# https://arxiv.org/abs/1709# https://deeplizard.com/learn/video/a-SnJtmBtyA.06560

# https://pythonprogramming.net/deep-q-l# https://deeplizard.com/learn/video/a-SnJtmBtyAearning-dqn-reinforcement-learning-python-tutorial/
# https://www.freecodecamp.org/news/an-introduction-to-deep-q-learning-lets-play-doom-54d02d8017d8/
# https://simoninithomas.github.io/Deep_reinforcement_learning_Course/
# https://lilianweng.github.io/lil-log/2018/05/05/implementing-deep-reinforcement-learning-models.html

# %%
import numpy as np
import random
import gym
from itertools import count
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Create an environment for a chosen game -- see docs for more games
env = gym.make('FrozenLake-v0', is_slippery=False)

# Show a few random moves on the environment
state = env.reset()
for t in range(5):
    #env.render()
    print("State:", state)
    action = env.action_space.sample()
    print("Action:", action)
    state, reward, done, info = env.step(action)
env.close()
# Out:
# State: 0
# Action: 3
# State: 0
# Action: 1
# State: 4
# Action: 2
# State: 5
# Action: 1
# State: 5
# Action: 1

# %%
# PARAMETERS

# Networks (agent)
in_shape = env.observation_space.n # Size of state space
print(f"State space length: {in_shape}")
out_shape = env.action_space.n         # Size of action space
print(f"Action space length: {out_shape}")

# Training
n_episodes = 5000       # Numper of epochs
memory_len = 50_000    # Length of replay memory
batch_size = 128
gamma      = 0.9        # Discount factor for Bellman equation

# Exploration rate
EPS_START = 0.9
EPS_END = 0.01
EPS_DECAY = 2000
# Out:
# State space length: 16
# Action space length: 4

# %%
def create_agent():
  '''Definition of agent'''
  model = Sequential()
  model.add(Dense(256, input_shape=(in_shape,), activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(16, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(out_shape, activation='linear', kernel_initializer='he_uniform'))
  model.compile(loss="hinge", optimizer='rmsprop')
  return model

# %%
# Create both networks
net_policy = create_agent()
net_target = create_agent()
net_target.set_weights(net_policy.get_weights())

net_policy.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 21,908
# Trainable params: 21,908
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample_action(state, eps):
  ''' Generate an action.
      Given the current exploration rate (defined by the number of samples taken
      so far, 'global samples_taken'), the action can be generated either
      by exploration (random) or exploitation (using current knowledge,
      i.e., current model and current state, 'state').
  '''
  # Sample by exploitation or exploration
  if np.random.uniform() > eps:
      state = to_categorical(state, in_shape).reshape(-1, in_shape)
      action = np.argmax(net_policy.predict(state))
  else:
      action = env.action_space.sample()
  return action

# %%
def init_mem_replay():
  experience = {"state": 0,
                "action": 0,
                "reward": 0,
                "next_state": 0
                }
  return [experience for _ in range(memory_len)]

# %%
def push_experience(state, action, reward, next_state):
  '''
  Stores experience in replay memory.
  Values of experience are encapsulated into a dictionary.
  Append if replay memory has not yet reached max length, or
  replace oldest register.
  '''
  experience = {"state": state,
                "action": action,
                "reward": reward,
                "next_state": next_state
                }
  replay_mem[push_count % memory_len] = experience

# %%
def decouple_batch(batch):
  states = []
  actions = []
  rewards = []
  next_states = []
  for experience in batch:
    states.append(experience['state'])
    actions.append(experience['action'])
    rewards.append(experience['reward'])
    next_states.append(experience['next_state'])
  return np.array(states), np.array(actions), np.array(rewards), np.array(next_states)

# %%
# Train - initialize environment
env = gym.make('FrozenLake-v0')

# Variables
samples_taken = 0
replay_mem = init_mem_replay()
push_count = 0
n_wins, max_wins = 0, 0 # Count consecutive wins
loss = 1
for episode in range(n_episodes):
  print(f"Episode:{episode+1:4d}/{n_episodes} --", end=' ')

  # Start episode and environment. Get initial state
  state = env.reset()
  for t_step in count():

    # Compute probability of exploration/exploitation given number of samples already taken
    eps = EPS_END + (EPS_START - EPS_END) * np.exp(-1. * samples_taken / EPS_DECAY)
    eps = max(eps, EPS_END)
    samples_taken += 1

    # Simulate one time step
    action = sample_action(state, eps)                    # Sample and action with prob eps
    next_state, reward, done, info = env.step(action)      # Evaluate sampled action

    # Evaluate status and adjust reward
    if done and reward == 0:
      reward = -100                 # we lost, give larger negative reward
    elif not done and reward == 0:
      reward = t_step               # still in the game, reward = num of time steps alive
    elif done and reward != 0:
      reward = 100                  # we won, give large positive reward
    
    # Populate replay memory
    push_experience(state, action, reward, next_state)    # Push new experience into replay memory
    push_count += 1                                       # Update count of pushes into memory
    state = next_state                                    # Update state as given by the last action

    # Optimization
    if push_count >= batch_size:
      # sample a random batch from replay memory
      batch = random.sample(replay_mem, batch_size)
      batch_states, batch_actions, batch_rewards, batch_next_states = decouple_batch(batch)

      # Compute q-values for current and next state, and update for the chosen action
      batch_states = to_categorical(batch_states, in_shape)
      batch_next_states = to_categorical(batch_next_states, in_shape)
      q_vals = net_policy.predict(batch_states)
      q_vals_next = net_target.predict(batch_next_states)
      
      # Updte Q-values by Bellman equation
      if not done:
        q_vals[range(len(q_vals)), batch_actions] = batch_rewards + (gamma * q_vals_next.max(axis=1))
      else:
        q_vals[range(len(q_vals)), batch_actions] = batch_rewards
          
      # Optimize policy network on current batch
      loss = net_policy.train_on_batch(batch_states, q_vals)

    # Update targets network
    #if done or push_count % 50 == 0:
    #    net_target.set_weights(net_policy.get_weights())

    # Check for episode termination
    if done:
      break
  
  net_target.set_weights(net_policy.get_weights())
  
  # Print episode's info
  if reward < 0:
    print(f" failed  ", end=' ')
    n_wins = 0
  elif reward > 0:
    print("*success*", end=' ')
    n_wins += 1
  max_wins = max(max_wins, n_wins)
  print(f"(wins={n_wins:2d}/{max_wins:2d})", end=' ')
  print(f"in {t_step+1:2d} t-steps, @state {state:2d}, eps={eps:.2f}({samples_taken}), loss={loss:.4f}")
    
env.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode:   2/5000 --  failed   (wins= 0/ 0) in  5 t-steps, @state  5, eps=0.89(23), loss=1.0000
# Episode:   3/5000 --  failed   (wins= 0/ 0) in  7 t-steps, @state  5, eps=0.89(30), loss=1.0000
# Episode:   4/5000 --  failed   (wins= 0/ 0) in  6 t-steps, @state  5, eps=0.88(36), loss=1.0000
# Episode:   5/5000 --  failed   (wins= 0/ 0) in  4 t-steps, @state  7, eps=0.88(40), loss=1.0000
# Episode:   6/5000 --  failed   (wins= 0/ 0) in 17 t-steps, @state  7, eps=0.88(57), loss=1.0000
# Episode:   7/5000 --  failed   (wins= 0/ 0) in 14 t-steps, @state  5, eps=0.87(71), loss=1.0000
# Episode:   8/5000 --  failed   (wins= 0/ 0) in 13 t-steps, @state  5, eps=0.86(84), loss=1.0000
# Episode:   9/5000 --  failed   (wins= 0/ 0) in  7 t-steps, @state  5, eps=0.86(91), loss=1.0000
# Episode:  10/5000 --  failed   (wins= 0/ 0) in  2 t-steps, @state  5, eps=0.86(93), loss=1.0000
# Episode:  11/5000 --  failed   (wins= 0/ 0) in 11 t-steps, @state 12, eps=0.86(104), loss=1.0000
# Episode:  12/5000 --  failed   (wins= 0/ 0) in  2 t-steps, @state  5, eps=0.85(106), loss=1.0000
# Episode:  13/5000 --  failed   (wins= 0/ 0) in  5 t-steps, @state  5, eps=0.85(111), loss=1.0000
# Episode:  14/5000 --  failed   (wins= 0/ 0) in 18 t-steps, @state 11, eps=0.84(129), loss=0.7171
# Episode:  15/5000 --  failed   (wins= 0/ 0) in 12 t-steps, @state 11, eps=0.84(141), loss=0.2500
# Episode:  16/5000 --  failed   (wins= 0/ 0) in  6 t-steps, @state  5, eps=0.84(147), loss=0.2500
# Episode:  17/5000 --  failed   (wins= 0/ 0) in  7 t-steps, @state  5, eps=0.83(154), loss=0.2500
# Episode:  18/5000 --  failed   (wins= 0/ 0) in  4 t-steps, @state  5, eps=0.83(158), loss=0.2491
# Episode:  19/5000 --  failed   (wins= 0/ 0) in  4 t-steps, @state  7, eps=0.83(162), loss=0.2500
# Episode:  20/5000 --  failed   (wins= 0/ 0) in 13 t-steps, @state  5, eps=0.83(175), loss=0.2500
# Episode:  21/5000 -- *success* (wins= 1/ 1) in 12 t-steps, @state 15, eps=0.82(187), loss=0.2500
# Episode:  22/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state  5, eps=0.81(208), loss=0.2500
# Episode:  23/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  7, eps=0.81(219), loss=0.2518
# Episode:  24/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  7, eps=0.80(227), loss=0.2500
# Episode:  25/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state 12, eps=0.80(236), loss=0.2999
# Episode:  26/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.80(244), loss=0.2500
# Episode:  27/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.80(246), loss=0.2500
# Episode:  28/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.80(250), loss=0.2523
# Episode:  29/5000 --  failed   (wins= 0/ 1) in 13 t-steps, @state  5, eps=0.79(263), loss=0.2512
# Episode:  30/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.79(268), loss=0.2562
# Episode:  31/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.79(273), loss=0.2480
# Episode:  32/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.78(283), loss=0.2500
# Episode:  33/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.78(291), loss=0.2500
# Episode:  34/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state 12, eps=0.78(303), loss=0.2600
# Episode:  35/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state 12, eps=0.77(308), loss=0.2581
# Episode:  36/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.77(310), loss=0.2494
# Episode:  37/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state 12, eps=0.77(315), loss=0.2500
# Episode:  38/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.77(318), loss=0.2500
# Episode:  39/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  7, eps=0.77(322), loss=0.2521
# Episode:  40/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state 12, eps=0.76(332), loss=0.2542
# Episode:  41/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.76(338), loss=0.2480
# Episode:  42/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.76(340), loss=0.2500
# Episode:  43/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.76(343), loss=0.2500
# Episode:  44/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.76(345), loss=0.2535
# Episode:  45/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  5, eps=0.75(357), loss=0.2500
# Episode:  46/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.75(359), loss=0.2500
# Episode:  47/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state  5, eps=0.75(380), loss=0.2531
# Episode:  48/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state 12, eps=0.74(387), loss=0.2500
# Episode:  49/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.74(395), loss=0.2500
# Episode:  50/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.74(400), loss=0.2547
# Episode:  51/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.74(407), loss=0.2500
# Episode:  52/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.73(413), loss=0.2588
# Episode:  53/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.73(416), loss=0.2480
# Episode:  54/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state 12, eps=0.73(427), loss=0.2500
# Episode:  55/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.73(433), loss=0.2500
# Episode:  56/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  5, eps=0.72(444), loss=0.2461
# Episode:  57/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.72(451), loss=0.2543
# Episode:  58/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.72(456), loss=0.2532
# Episode:  59/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state 12, eps=0.72(467), loss=0.2538
# Episode:  60/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.71(469), loss=0.2501
# Episode:  61/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.71(473), loss=0.2500
# Episode:  62/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  5, eps=0.71(484), loss=0.2500
# Episode:  63/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.71(491), loss=0.2500
# Episode:  64/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.71(494), loss=0.2500
# Episode:  65/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state 12, eps=0.70(515), loss=0.2500
# Episode:  66/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.70(517), loss=0.4149
# Episode:  67/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.70(519), loss=0.2500
# Episode:  68/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  5, eps=0.69(530), loss=0.2587
# Episode:  69/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  5, eps=0.69(542), loss=0.2480
# Episode:  70/5000 --  failed   (wins= 0/ 1) in 19 t-steps, @state  5, eps=0.68(561), loss=0.2500
# Episode:  71/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  5, eps=0.68(572), loss=0.2500
# Episode:  72/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.68(575), loss=0.2500
# Episode:  73/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.68(577), loss=0.2633
# Episode:  74/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  7, eps=0.67(586), loss=0.2566
# Episode:  75/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state 12, eps=0.67(592), loss=0.2605
# Episode:  76/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state 12, eps=0.67(602), loss=0.2546
# Episode:  77/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  7, eps=0.67(607), loss=0.2500
# Episode:  78/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.67(609), loss=0.2539
# Episode:  79/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  7, eps=0.66(616), loss=0.2560
# Episode:  80/5000 --  failed   (wins= 0/ 1) in 24 t-steps, @state  5, eps=0.66(640), loss=0.2819
# Episode:  81/5000 --  failed   (wins= 0/ 1) in 30 t-steps, @state  5, eps=0.65(670), loss=0.2629
# Episode:  82/5000 --  failed   (wins= 0/ 1) in 13 t-steps, @state  5, eps=0.64(683), loss=0.2657
# Episode:  83/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state 12, eps=0.64(704), loss=0.2538
# Episode:  84/5000 --  failed   (wins= 0/ 1) in 26 t-steps, @state  5, eps=0.63(730), loss=0.2500
# Episode:  85/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.63(735), loss=0.2511
# Episode:  86/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.63(737), loss=0.3190
# Episode:  87/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state 12, eps=0.62(742), loss=0.2480
# Episode:  88/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.62(748), loss=0.2580
# Episode:  89/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.62(753), loss=0.2480
# Episode:  90/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  7, eps=0.62(761), loss=0.4212
# Episode:  91/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.62(766), loss=0.2538
# Episode:  92/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state 12, eps=0.62(770), loss=0.2537
# Episode:  93/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.61(773), loss=0.2687
# Episode:  94/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state 12, eps=0.61(779), loss=0.2502
# Episode:  95/5000 -- *success* (wins= 1/ 1) in  7 t-steps, @state 15, eps=0.61(786), loss=0.2500
# Episode:  96/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.61(793), loss=0.2717
# Episode:  97/5000 --  failed   (wins= 0/ 1) in 24 t-steps, @state  5, eps=0.60(817), loss=0.2506
# Episode:  98/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.60(822), loss=0.2500
# Episode:  99/5000 --  failed   (wins= 0/ 1) in 22 t-steps, @state  5, eps=0.59(844), loss=0.3036
# Episode: 100/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state 12, eps=0.59(855), loss=0.2509
# Episode: 101/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state 12, eps=0.59(863), loss=0.2535
# Episode: 102/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.59(871), loss=0.2616
# Episode: 103/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state 11, eps=0.58(880), loss=0.3202
# Episode: 104/5000 --  failed   (wins= 0/ 1) in 33 t-steps, @state 12, eps=0.57(913), loss=0.4804
# Episode: 105/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  7, eps=0.57(923), loss=0.2650
# Episode: 106/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  5, eps=0.57(935), loss=0.2829
# Episode: 107/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.57(938), loss=0.2604
# Episode: 108/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.57(941), loss=0.2537
# Episode: 109/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state 12, eps=0.56(946), loss=0.2548
# Episode: 110/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.56(948), loss=0.2573
# Episode: 111/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  5, eps=0.56(957), loss=0.2549
# Episode: 112/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.56(967), loss=0.2527
# Episode: 113/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.56(971), loss=0.2715
# Episode: 114/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.56(981), loss=0.2521
# Episode: 115/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  7, eps=0.55(990), loss=0.2500
# Episode: 116/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.55(992), loss=0.2510
# Episode: 117/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state 12, eps=0.55(997), loss=0.2500
# Episode: 118/5000 --  failed   (wins= 0/ 1) in 17 t-steps, @state  5, eps=0.55(1014), loss=0.2489
# Episode: 119/5000 --  failed   (wins= 0/ 1) in 18 t-steps, @state 12, eps=0.54(1032), loss=0.2670
# Episode: 120/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state 12, eps=0.54(1041), loss=0.2553
# Episode: 121/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.54(1048), loss=0.2656
# Episode: 122/5000 --  failed   (wins= 0/ 1) in 26 t-steps, @state  5, eps=0.53(1074), loss=0.2558
# Episode: 123/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  5, eps=0.53(1083), loss=0.3147
# Episode: 124/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.53(1091), loss=0.2500
# Episode: 125/5000 --  failed   (wins= 0/ 1) in 41 t-steps, @state  5, eps=0.52(1132), loss=0.2573
# Episode: 126/5000 --  failed   (wins= 0/ 1) in 32 t-steps, @state 12, eps=0.51(1164), loss=0.2665
# Episode: 127/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.51(1167), loss=0.2587
# Episode: 128/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.51(1172), loss=0.2511
# Episode: 129/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  7, eps=0.50(1181), loss=0.2892
# Episode: 130/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state 11, eps=0.50(1202), loss=0.3363
# Episode: 131/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.50(1205), loss=0.2500
# Episode: 132/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.50(1213), loss=0.2836
# Episode: 133/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  7, eps=0.49(1224), loss=0.2520
# Episode: 134/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  5, eps=0.49(1233), loss=0.2537
# Episode: 135/5000 --  failed   (wins= 0/ 1) in 16 t-steps, @state 12, eps=0.49(1249), loss=0.2887
# Episode: 136/5000 --  failed   (wins= 0/ 1) in 27 t-steps, @state  5, eps=0.48(1276), loss=0.3256
# Episode: 137/5000 --  failed   (wins= 0/ 1) in 15 t-steps, @state  5, eps=0.48(1291), loss=0.2571
# Episode: 138/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state 12, eps=0.48(1298), loss=0.2555
# Episode: 139/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.47(1300), loss=0.2531
# Episode: 140/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state 12, eps=0.47(1308), loss=0.2496
# Episode: 141/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state  5, eps=0.47(1329), loss=0.2553
# Episode: 142/5000 --  failed   (wins= 0/ 1) in 27 t-steps, @state  5, eps=0.46(1356), loss=0.2629
# Episode: 143/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.46(1358), loss=0.2737
# Episode: 144/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  7, eps=0.46(1363), loss=0.2461
# Episode: 145/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  5, eps=0.46(1375), loss=0.2518
# Episode: 146/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.46(1381), loss=0.2856
# Episode: 147/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.46(1384), loss=0.2573
# Episode: 148/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  7, eps=0.45(1395), loss=0.2563
# Episode: 149/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.45(1399), loss=0.2480
# Episode: 150/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.45(1406), loss=0.2891
# Episode: 151/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.45(1412), loss=0.3077
# Episode: 152/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state 11, eps=0.45(1422), loss=0.2608
# Episode: 153/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.45(1432), loss=0.2503
# Episode: 154/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.44(1438), loss=0.2587
# Episode: 155/5000 --  failed   (wins= 0/ 1) in 22 t-steps, @state  5, eps=0.44(1460), loss=0.3806
# Episode: 156/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.44(1467), loss=0.2941
# Episode: 157/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.44(1475), loss=0.2513
# Episode: 158/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.43(1482), loss=0.2548
# Episode: 159/5000 --  failed   (wins= 0/ 1) in 17 t-steps, @state  5, eps=0.43(1499), loss=0.2519
# Episode: 160/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.43(1505), loss=0.2617
# Episode: 161/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.43(1513), loss=0.2498
# Episode: 162/5000 --  failed   (wins= 0/ 1) in 20 t-steps, @state  5, eps=0.42(1533), loss=0.2595
# Episode: 163/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.42(1537), loss=0.3474
# Episode: 164/5000 --  failed   (wins= 0/ 1) in 28 t-steps, @state  5, eps=0.42(1565), loss=0.2500
# Episode: 165/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state 12, eps=0.41(1577), loss=0.2526
# Episode: 166/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.41(1582), loss=0.2709
# Episode: 167/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.41(1584), loss=0.2695
# Episode: 168/5000 --  failed   (wins= 0/ 1) in 18 t-steps, @state  5, eps=0.41(1602), loss=0.2686
# Episode: 169/5000 --  failed   (wins= 0/ 1) in 26 t-steps, @state  7, eps=0.40(1628), loss=0.2566
# Episode: 170/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state 12, eps=0.40(1631), loss=0.2552
# Episode: 171/5000 --  failed   (wins= 0/ 1) in 14 t-steps, @state 12, eps=0.40(1645), loss=0.2517
# Episode: 172/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  7, eps=0.40(1657), loss=0.2492
# Episode: 173/5000 --  failed   (wins= 0/ 1) in 16 t-steps, @state 11, eps=0.40(1673), loss=0.2588
# Episode: 174/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.39(1681), loss=0.2674
# Episode: 175/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  5, eps=0.39(1690), loss=0.2592
# Episode: 176/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.39(1696), loss=0.2500
# Episode: 177/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.39(1702), loss=0.2550
# Episode: 178/5000 --  failed   (wins= 0/ 1) in 34 t-steps, @state  5, eps=0.38(1736), loss=0.2590
# Episode: 179/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.38(1741), loss=0.2613
# Episode: 180/5000 --  failed   (wins= 0/ 1) in 18 t-steps, @state  7, eps=0.38(1759), loss=0.2629
# Episode: 181/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.38(1766), loss=0.2693
# Episode: 182/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  5, eps=0.38(1773), loss=0.2556
# Episode: 183/5000 --  failed   (wins= 0/ 1) in 24 t-steps, @state  5, eps=0.37(1797), loss=0.2901
# Episode: 184/5000 --  failed   (wins= 0/ 1) in 14 t-steps, @state 12, eps=0.37(1811), loss=0.2555
# Episode: 185/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state 11, eps=0.37(1817), loss=0.2632
# Episode: 186/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state 12, eps=0.37(1824), loss=0.2618
# Episode: 187/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state 12, eps=0.37(1831), loss=0.2513
# Episode: 188/5000 --  failed   (wins= 0/ 1) in 20 t-steps, @state  5, eps=0.36(1851), loss=0.2532
# Episode: 189/5000 --  failed   (wins= 0/ 1) in 27 t-steps, @state  5, eps=0.36(1878), loss=0.2668
# Episode: 190/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state  7, eps=0.36(1885), loss=0.2559
# Episode: 191/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state 11, eps=0.36(1895), loss=0.2874
# Episode: 192/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state 11, eps=0.35(1903), loss=0.2614
# Episode: 193/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  5, eps=0.35(1912), loss=0.2624
# Episode: 194/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.35(1917), loss=0.2520
# Episode: 195/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  5, eps=0.35(1928), loss=0.2472
# Episode: 196/5000 --  failed   (wins= 0/ 1) in 17 t-steps, @state  5, eps=0.35(1945), loss=0.2492
# Episode: 197/5000 --  failed   (wins= 0/ 1) in 33 t-steps, @state  5, eps=0.34(1978), loss=0.2733
# Episode: 198/5000 --  failed   (wins= 0/ 1) in 22 t-steps, @state  7, eps=0.34(2000), loss=0.2487
# Episode: 199/5000 --  failed   (wins= 0/ 1) in 13 t-steps, @state  7, eps=0.34(2013), loss=0.2480
# Episode: 200/5000 --  failed   (wins= 0/ 1) in 21 t-steps, @state 11, eps=0.33(2034), loss=0.2614
# Episode: 201/5000 --  failed   (wins= 0/ 1) in 29 t-steps, @state  5, eps=0.33(2063), loss=0.2740
# Episode: 202/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.33(2068), loss=0.2593
# Episode: 203/5000 --  failed   (wins= 0/ 1) in 14 t-steps, @state  5, eps=0.32(2082), loss=0.2669
# Episode: 204/5000 --  failed   (wins= 0/ 1) in 12 t-steps, @state  5, eps=0.32(2094), loss=0.2573
# Episode: 205/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.32(2104), loss=0.2537
# Episode: 206/5000 --  failed   (wins= 0/ 1) in 20 t-steps, @state  5, eps=0.32(2124), loss=0.2540
# Episode: 207/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.32(2126), loss=0.2700
# Episode: 208/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state 12, eps=0.32(2137), loss=0.2872
# Episode: 209/5000 --  failed   (wins= 0/ 1) in  2 t-steps, @state  5, eps=0.32(2139), loss=0.2611
# Episode: 210/5000 --  failed   (wins= 0/ 1) in  3 t-steps, @state  5, eps=0.32(2142), loss=0.2720
# Episode: 211/5000 --  failed   (wins= 0/ 1) in  6 t-steps, @state  5, eps=0.31(2148), loss=0.2441
# Episode: 212/5000 --  failed   (wins= 0/ 1) in  9 t-steps, @state  7, eps=0.31(2157), loss=0.3023
# Episode: 213/5000 --  failed   (wins= 0/ 1) in  5 t-steps, @state  5, eps=0.31(2162), loss=0.2630
# Episode: 214/5000 --  failed   (wins= 0/ 1) in 17 t-steps, @state  5, eps=0.31(2179), loss=0.2647
# Episode: 215/5000 --  failed   (wins= 0/ 1) in 11 t-steps, @state  7, eps=0.31(2190), loss=0.2620
# Episode: 216/5000 --  failed   (wins= 0/ 1) in 33 t-steps, @state 12, eps=0.30(2223), loss=0.2886
# Episode: 217/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  7, eps=0.30(2227), loss=0.2605
# Episode: 218/5000 --  failed   (wins= 0/ 1) in  4 t-steps, @state  5, eps=0.30(2231), loss=0.2692
# Episode: 219/5000 --  failed   (wins= 0/ 1) in  7 t-steps, @state 12, eps=0.30(2238), loss=0.2680
# Episode: 220/5000 --  failed   (wins= 0/ 1) in 10 t-steps, @state  5, eps=0.30(2248), loss=0.2645
# Episode: 221/5000 --  failed   (wins= 0/ 1) in  8 t-steps, @state  5, eps=0.30(2256), loss=0.2611
# Episode: 222/5000 --  failed   (wins= 0/ 1) in 32 t-steps, @state  7, eps=0.29(2288), loss=0.2677
# Episode: 223/5000 -- *success* (wins= 1/ 1) in 14 t-steps, @state 15, eps=0.29(2302), loss=0.2882
# Episode: 224/5000 -- *success* (wins= 2/ 2) in  9 t-steps, @state 15, eps=0.29(2311), loss=0.2497
# Episode: 225/5000 --  failed   (wins= 0/ 2) in 21 t-steps, @state  7, eps=0.29(2332), loss=0.2601
# Episode: 226/5000 --  failed   (wins= 0/ 2) in  2 t-steps, @state  5, eps=0.29(2334), loss=0.2763
# Episode: 227/5000 --  failed   (wins= 0/ 2) in 64 t-steps, @state  5, eps=0.28(2398), loss=0.2618
# Episode: 228/5000 --  failed   (wins= 0/ 2) in 13 t-steps, @state  5, eps=0.28(2411), loss=0.2430
# Episode: 229/5000 --  failed   (wins= 0/ 2) in 19 t-steps, @state  5, eps=0.27(2430), loss=0.2623
# Episode: 230/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state  5, eps=0.27(2433), loss=0.2728
# Episode: 231/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  5, eps=0.27(2455), loss=0.2489
# Episode: 232/5000 --  failed   (wins= 0/ 2) in  5 t-steps, @state  5, eps=0.27(2460), loss=0.2584
# Episode: 233/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state 12, eps=0.27(2469), loss=0.2902
# Episode: 234/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.27(2475), loss=0.2773
# Episode: 235/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state 12, eps=0.27(2483), loss=0.2586
# Episode: 236/5000 --  failed   (wins= 0/ 2) in 32 t-steps, @state 11, eps=0.26(2515), loss=0.2901
# Episode: 237/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state 11, eps=0.26(2529), loss=0.2608
# Episode: 238/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state  5, eps=0.26(2532), loss=0.2625
# Episode: 239/5000 --  failed   (wins= 0/ 2) in 32 t-steps, @state  5, eps=0.26(2564), loss=0.2478
# Episode: 240/5000 --  failed   (wins= 0/ 2) in 18 t-steps, @state  5, eps=0.25(2582), loss=0.2642
# Episode: 241/5000 --  failed   (wins= 0/ 2) in  4 t-steps, @state  5, eps=0.25(2586), loss=0.2598
# Episode: 242/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  5, eps=0.25(2595), loss=0.2499
# Episode: 243/5000 -- *success* (wins= 1/ 2) in 16 t-steps, @state 15, eps=0.25(2611), loss=0.2517
# Episode: 244/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.25(2617), loss=0.2791
# Episode: 245/5000 --  failed   (wins= 0/ 2) in 18 t-steps, @state 11, eps=0.25(2635), loss=0.2594
# Episode: 246/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  5, eps=0.25(2644), loss=0.2706
# Episode: 247/5000 --  failed   (wins= 0/ 2) in 30 t-steps, @state  5, eps=0.24(2674), loss=0.2592
# Episode: 248/5000 --  failed   (wins= 0/ 2) in 28 t-steps, @state  5, eps=0.24(2702), loss=0.2758
# Episode: 249/5000 --  failed   (wins= 0/ 2) in  2 t-steps, @state  5, eps=0.24(2704), loss=0.2827
# Episode: 250/5000 --  failed   (wins= 0/ 2) in 15 t-steps, @state 12, eps=0.24(2719), loss=0.3072
# Episode: 251/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  5, eps=0.24(2727), loss=0.2756
# Episode: 252/5000 --  failed   (wins= 0/ 2) in 43 t-steps, @state 11, eps=0.23(2770), loss=0.2740
# Episode: 253/5000 --  failed   (wins= 0/ 2) in  2 t-steps, @state  5, eps=0.23(2772), loss=0.2823
# Episode: 254/5000 --  failed   (wins= 0/ 2) in 11 t-steps, @state  7, eps=0.23(2783), loss=0.2560
# Episode: 255/5000 --  failed   (wins= 0/ 2) in 25 t-steps, @state  5, eps=0.23(2808), loss=0.3285
# Episode: 256/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  5, eps=0.23(2815), loss=0.2567
# Episode: 257/5000 --  failed   (wins= 0/ 2) in 33 t-steps, @state  5, eps=0.22(2848), loss=0.2593
# Episode: 258/5000 --  failed   (wins= 0/ 2) in 30 t-steps, @state  7, eps=0.22(2878), loss=0.2631
# Episode: 259/5000 --  failed   (wins= 0/ 2) in 38 t-steps, @state 12, eps=0.22(2916), loss=0.3330
# Episode: 260/5000 --  failed   (wins= 0/ 2) in 15 t-steps, @state  7, eps=0.22(2931), loss=0.2588
# Episode: 261/5000 --  failed   (wins= 0/ 2) in 57 t-steps, @state  7, eps=0.21(2988), loss=0.2768
# Episode: 262/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state 11, eps=0.21(3002), loss=0.2609
# Episode: 263/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  5, eps=0.21(3010), loss=0.2551
# Episode: 264/5000 --  failed   (wins= 0/ 2) in  4 t-steps, @state  5, eps=0.21(3014), loss=0.3424
# Episode: 265/5000 --  failed   (wins= 0/ 2) in 34 t-steps, @state  5, eps=0.20(3048), loss=0.2803
# Episode: 266/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  7, eps=0.20(3056), loss=0.3111
# Episode: 267/5000 --  failed   (wins= 0/ 2) in 11 t-steps, @state  5, eps=0.20(3067), loss=0.2768
# Episode: 268/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  5, eps=0.20(3074), loss=0.2597
# Episode: 269/5000 --  failed   (wins= 0/ 2) in 26 t-steps, @state  5, eps=0.20(3100), loss=0.2937
# Episode: 270/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state 12, eps=0.20(3109), loss=0.2519
# Episode: 271/5000 --  failed   (wins= 0/ 2) in 15 t-steps, @state 12, eps=0.20(3124), loss=0.2613
# Episode: 272/5000 --  failed   (wins= 0/ 2) in 24 t-steps, @state  7, eps=0.19(3148), loss=0.3244
# Episode: 273/5000 --  failed   (wins= 0/ 2) in 30 t-steps, @state  5, eps=0.19(3178), loss=0.2735
# Episode: 274/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  7, eps=0.19(3184), loss=0.2802
# Episode: 275/5000 --  failed   (wins= 0/ 2) in 17 t-steps, @state  5, eps=0.19(3201), loss=0.2678
# Episode: 276/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  5, eps=0.19(3208), loss=0.2590
# Episode: 277/5000 -- *success* (wins= 1/ 2) in 31 t-steps, @state 15, eps=0.19(3239), loss=0.2730
# Episode: 278/5000 --  failed   (wins= 0/ 2) in  5 t-steps, @state  7, eps=0.19(3244), loss=0.3159
# Episode: 279/5000 --  failed   (wins= 0/ 2) in 30 t-steps, @state  5, eps=0.18(3274), loss=0.3075
# Episode: 280/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state 12, eps=0.18(3288), loss=0.3046
# Episode: 281/5000 --  failed   (wins= 0/ 2) in 27 t-steps, @state  5, eps=0.18(3315), loss=0.2714
# Episode: 282/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  7, eps=0.18(3323), loss=0.2554
# Episode: 283/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state 12, eps=0.18(3345), loss=0.2592
# Episode: 284/5000 --  failed   (wins= 0/ 2) in  2 t-steps, @state  5, eps=0.18(3347), loss=0.3029
# Episode: 285/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state  5, eps=0.18(3350), loss=0.2855
# Episode: 286/5000 --  failed   (wins= 0/ 2) in 23 t-steps, @state 12, eps=0.17(3373), loss=0.2575
# Episode: 287/5000 --  failed   (wins= 0/ 2) in 23 t-steps, @state 11, eps=0.17(3396), loss=0.2980
# Episode: 288/5000 --  failed   (wins= 0/ 2) in 11 t-steps, @state  5, eps=0.17(3407), loss=0.2982
# Episode: 289/5000 -- *success* (wins= 1/ 2) in 38 t-steps, @state 15, eps=0.17(3445), loss=0.3000
# Episode: 290/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state 11, eps=0.17(3459), loss=0.2856
# Episode: 291/5000 --  failed   (wins= 0/ 2) in 39 t-steps, @state  7, eps=0.16(3498), loss=0.3128
# Episode: 292/5000 --  failed   (wins= 0/ 2) in 25 t-steps, @state  5, eps=0.16(3523), loss=0.2510
# Episode: 293/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state  7, eps=0.16(3537), loss=0.2822
# Episode: 294/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  7, eps=0.16(3559), loss=0.2620
# Episode: 295/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state 12, eps=0.16(3565), loss=0.2732
# Episode: 296/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state 12, eps=0.16(3571), loss=0.2559
# Episode: 297/5000 --  failed   (wins= 0/ 2) in 19 t-steps, @state  5, eps=0.16(3590), loss=0.2620
# Episode: 298/5000 --  failed   (wins= 0/ 2) in 26 t-steps, @state  5, eps=0.16(3616), loss=0.2753
# Episode: 299/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  5, eps=0.16(3623), loss=0.2607
# Episode: 300/5000 --  failed   (wins= 0/ 2) in 16 t-steps, @state  5, eps=0.15(3639), loss=0.2754
# Episode: 301/5000 --  failed   (wins= 0/ 2) in 26 t-steps, @state  7, eps=0.15(3665), loss=0.2486
# Episode: 302/5000 --  failed   (wins= 0/ 2) in 30 t-steps, @state  7, eps=0.15(3695), loss=0.2969
# Episode: 303/5000 --  failed   (wins= 0/ 2) in 23 t-steps, @state  7, eps=0.15(3718), loss=0.2634
# Episode: 304/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state 12, eps=0.15(3721), loss=0.2697
# Episode: 305/5000 --  failed   (wins= 0/ 2) in  2 t-steps, @state  5, eps=0.15(3723), loss=0.2597
# Episode: 306/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  5, eps=0.15(3731), loss=0.2688
# Episode: 307/5000 --  failed   (wins= 0/ 2) in 13 t-steps, @state  5, eps=0.15(3744), loss=0.2704
# Episode: 308/5000 --  failed   (wins= 0/ 2) in 56 t-steps, @state  7, eps=0.14(3800), loss=0.2557
# Episode: 309/5000 --  failed   (wins= 0/ 2) in 15 t-steps, @state  5, eps=0.14(3815), loss=0.2860
# Episode: 310/5000 --  failed   (wins= 0/ 2) in 11 t-steps, @state  7, eps=0.14(3826), loss=0.2764
# Episode: 311/5000 --  failed   (wins= 0/ 2) in 37 t-steps, @state 12, eps=0.14(3863), loss=0.2660
# Episode: 312/5000 --  failed   (wins= 0/ 2) in 20 t-steps, @state  7, eps=0.14(3883), loss=0.2687
# Episode: 313/5000 --  failed   (wins= 0/ 2) in 19 t-steps, @state 12, eps=0.14(3902), loss=0.2598
# Episode: 314/5000 --  failed   (wins= 0/ 2) in 38 t-steps, @state  5, eps=0.13(3940), loss=0.2968
# Episode: 315/5000 --  failed   (wins= 0/ 2) in 23 t-steps, @state  7, eps=0.13(3963), loss=0.2559
# Episode: 316/5000 --  failed   (wins= 0/ 2) in  4 t-steps, @state  5, eps=0.13(3967), loss=0.3061
# Episode: 317/5000 --  failed   (wins= 0/ 2) in 25 t-steps, @state 12, eps=0.13(3992), loss=0.2918
# Episode: 318/5000 --  failed   (wins= 0/ 2) in 37 t-steps, @state  5, eps=0.13(4029), loss=0.2817
# Episode: 319/5000 --  failed   (wins= 0/ 2) in 84 t-steps, @state  7, eps=0.12(4113), loss=0.2612
# Episode: 320/5000 --  failed   (wins= 0/ 2) in 60 t-steps, @state 11, eps=0.12(4173), loss=0.3559
# Episode: 321/5000 --  failed   (wins= 0/ 2) in 48 t-steps, @state  5, eps=0.12(4221), loss=0.2651
# Episode: 322/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  5, eps=0.12(4243), loss=0.3264
# Episode: 323/5000 -- *success* (wins= 1/ 2) in 71 t-steps, @state 15, eps=0.11(4314), loss=0.3060
# Episode: 324/5000 --  failed   (wins= 0/ 2) in 37 t-steps, @state  7, eps=0.11(4351), loss=0.2935
# Episode: 325/5000 --  failed   (wins= 0/ 2) in 12 t-steps, @state  7, eps=0.11(4363), loss=0.2894
# Episode: 326/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state  7, eps=0.11(4377), loss=0.2630
# Episode: 327/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  5, eps=0.11(4399), loss=0.2659
# Episode: 328/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.11(4405), loss=0.2834
# Episode: 329/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  5, eps=0.11(4414), loss=0.2647
# Episode: 330/5000 --  failed   (wins= 0/ 2) in 100 t-steps, @state  8, eps=0.10(4514), loss=0.2786
# Episode: 331/5000 -- *success* (wins= 1/ 2) in 14 t-steps, @state 15, eps=0.10(4528), loss=0.2585
# Episode: 332/5000 --  failed   (wins= 0/ 2) in 38 t-steps, @state  7, eps=0.10(4566), loss=0.2622
# Episode: 333/5000 --  failed   (wins= 0/ 2) in 29 t-steps, @state  7, eps=0.10(4595), loss=0.2708
# Episode: 334/5000 --  failed   (wins= 0/ 2) in 40 t-steps, @state  7, eps=0.10(4635), loss=0.2627
# Episode: 335/5000 --  failed   (wins= 0/ 2) in 25 t-steps, @state  5, eps=0.10(4660), loss=0.2710
# Episode: 336/5000 --  failed   (wins= 0/ 2) in 45 t-steps, @state  5, eps=0.09(4705), loss=0.3222
# Episode: 337/5000 --  failed   (wins= 0/ 2) in 38 t-steps, @state 11, eps=0.09(4743), loss=0.2680
# Episode: 338/5000 -- *success* (wins= 1/ 2) in 26 t-steps, @state 15, eps=0.09(4769), loss=0.2842
# Episode: 339/5000 --  failed   (wins= 0/ 2) in 49 t-steps, @state  7, eps=0.09(4818), loss=0.2825
# Episode: 340/5000 --  failed   (wins= 0/ 2) in 35 t-steps, @state 12, eps=0.09(4853), loss=0.3567
# Episode: 341/5000 --  failed   (wins= 0/ 2) in 20 t-steps, @state  7, eps=0.09(4873), loss=0.2862
# Episode: 342/5000 --  failed   (wins= 0/ 2) in  4 t-steps, @state  7, eps=0.09(4877), loss=0.2870
# Episode: 343/5000 --  failed   (wins= 0/ 2) in  8 t-steps, @state  5, eps=0.09(4885), loss=0.3165
# Episode: 344/5000 --  failed   (wins= 0/ 2) in 21 t-steps, @state  5, eps=0.09(4906), loss=0.2773
# Episode: 345/5000 --  failed   (wins= 0/ 2) in 14 t-steps, @state  5, eps=0.09(4920), loss=0.2800
# Episode: 346/5000 --  failed   (wins= 0/ 2) in 85 t-steps, @state  5, eps=0.08(5005), loss=0.3743
# Episode: 347/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state 12, eps=0.08(5008), loss=0.3082
# Episode: 348/5000 --  failed   (wins= 0/ 2) in 36 t-steps, @state 12, eps=0.08(5044), loss=0.2894
# Episode: 349/5000 --  failed   (wins= 0/ 2) in 12 t-steps, @state  7, eps=0.08(5056), loss=0.3963
# Episode: 350/5000 --  failed   (wins= 0/ 2) in  5 t-steps, @state  5, eps=0.08(5061), loss=0.2658
# Episode: 351/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.08(5067), loss=0.2532
# Episode: 352/5000 --  failed   (wins= 0/ 2) in 26 t-steps, @state  5, eps=0.08(5093), loss=0.2786
# Episode: 353/5000 --  failed   (wins= 0/ 2) in 50 t-steps, @state  7, eps=0.08(5143), loss=0.2535
# Episode: 354/5000 --  failed   (wins= 0/ 2) in 51 t-steps, @state  5, eps=0.08(5194), loss=0.3643
# Episode: 355/5000 --  failed   (wins= 0/ 2) in 52 t-steps, @state  7, eps=0.07(5246), loss=0.2697
# Episode: 356/5000 --  failed   (wins= 0/ 2) in 62 t-steps, @state  5, eps=0.07(5308), loss=0.2533
# Episode: 357/5000 --  failed   (wins= 0/ 2) in 26 t-steps, @state  7, eps=0.07(5334), loss=0.2926
# Episode: 358/5000 --  failed   (wins= 0/ 2) in 12 t-steps, @state  5, eps=0.07(5346), loss=0.2740
# Episode: 359/5000 --  failed   (wins= 0/ 2) in 68 t-steps, @state  5, eps=0.07(5414), loss=0.2913
# Episode: 360/5000 -- *success* (wins= 1/ 2) in 30 t-steps, @state 15, eps=0.07(5444), loss=0.2589
# Episode: 361/5000 --  failed   (wins= 0/ 2) in 12 t-steps, @state  7, eps=0.07(5456), loss=0.2928
# Episode: 362/5000 --  failed   (wins= 0/ 2) in 13 t-steps, @state  7, eps=0.07(5469), loss=0.2619
# Episode: 363/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  7, eps=0.07(5478), loss=0.4147
# Episode: 364/5000 --  failed   (wins= 0/ 2) in 56 t-steps, @state  5, eps=0.07(5534), loss=0.2797
# Episode: 365/5000 --  failed   (wins= 0/ 2) in 68 t-steps, @state  7, eps=0.06(5602), loss=0.2841
# Episode: 366/5000 --  failed   (wins= 0/ 2) in 10 t-steps, @state  7, eps=0.06(5612), loss=0.2890
# Episode: 367/5000 --  failed   (wins= 0/ 2) in 48 t-steps, @state  7, eps=0.06(5660), loss=0.2573
# Episode: 368/5000 --  failed   (wins= 0/ 2) in 12 t-steps, @state  5, eps=0.06(5672), loss=0.4228
# Episode: 369/5000 --  failed   (wins= 0/ 2) in 100 t-steps, @state 10, eps=0.06(5772), loss=0.2568
# Episode: 370/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  5, eps=0.06(5781), loss=0.2808
# Episode: 371/5000 --  failed   (wins= 0/ 2) in 100 t-steps, @state  9, eps=0.06(5881), loss=0.2744
# Episode: 372/5000 --  failed   (wins= 0/ 2) in 27 t-steps, @state  5, eps=0.06(5908), loss=0.2712
# Episode: 373/5000 --  failed   (wins= 0/ 2) in  9 t-steps, @state  7, eps=0.06(5917), loss=0.2880
# Episode: 374/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  7, eps=0.06(5939), loss=0.2585
# Episode: 375/5000 --  failed   (wins= 0/ 2) in 46 t-steps, @state  7, eps=0.05(5985), loss=0.2819
# Episode: 376/5000 --  failed   (wins= 0/ 2) in 33 t-steps, @state  7, eps=0.05(6018), loss=0.3297
# Episode: 377/5000 --  failed   (wins= 0/ 2) in 19 t-steps, @state  5, eps=0.05(6037), loss=0.2678
# Episode: 378/5000 --  failed   (wins= 0/ 2) in  5 t-steps, @state  7, eps=0.05(6042), loss=0.2820
# Episode: 379/5000 --  failed   (wins= 0/ 2) in 40 t-steps, @state  7, eps=0.05(6082), loss=0.2546
# Episode: 380/5000 --  failed   (wins= 0/ 2) in 84 t-steps, @state  7, eps=0.05(6166), loss=0.2697
# Episode: 381/5000 --  failed   (wins= 0/ 2) in 100 t-steps, @state  0, eps=0.05(6266), loss=0.2789
# Episode: 382/5000 --  failed   (wins= 0/ 2) in 41 t-steps, @state  5, eps=0.05(6307), loss=0.3454
# Episode: 383/5000 -- *success* (wins= 1/ 2) in 14 t-steps, @state 15, eps=0.05(6321), loss=0.3100
# Episode: 384/5000 -- *success* (wins= 2/ 2) in 30 t-steps, @state 15, eps=0.05(6351), loss=0.2912
# Episode: 385/5000 --  failed   (wins= 0/ 2) in 32 t-steps, @state  7, eps=0.05(6383), loss=0.2791
# Episode: 386/5000 --  failed   (wins= 0/ 2) in 59 t-steps, @state  7, eps=0.05(6442), loss=0.2826
# Episode: 387/5000 -- *success* (wins= 1/ 2) in 27 t-steps, @state 15, eps=0.05(6469), loss=0.2718
# Episode: 388/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  7, eps=0.04(6476), loss=0.2670
# Episode: 389/5000 -- *success* (wins= 1/ 2) in 43 t-steps, @state 15, eps=0.04(6519), loss=0.5289
# Episode: 390/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state 12, eps=0.04(6525), loss=0.3090
# Episode: 391/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state 12, eps=0.04(6528), loss=0.2889
# Episode: 392/5000 --  failed   (wins= 0/ 2) in 39 t-steps, @state  5, eps=0.04(6567), loss=0.3186
# Episode: 393/5000 --  failed   (wins= 0/ 2) in 23 t-steps, @state  7, eps=0.04(6590), loss=0.3010
# Episode: 394/5000 -- *success* (wins= 1/ 2) in 37 t-steps, @state 15, eps=0.04(6627), loss=0.2604
# Episode: 395/5000 --  failed   (wins= 0/ 2) in 20 t-steps, @state 12, eps=0.04(6647), loss=0.2809
# Episode: 396/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.04(6653), loss=0.3416
# Episode: 397/5000 --  failed   (wins= 0/ 2) in  4 t-steps, @state 12, eps=0.04(6657), loss=0.2619
# Episode: 398/5000 --  failed   (wins= 0/ 2) in  3 t-steps, @state 12, eps=0.04(6660), loss=0.2571
# Episode: 399/5000 --  failed   (wins= 0/ 2) in 36 t-steps, @state  7, eps=0.04(6696), loss=0.3193
# Episode: 400/5000 --  failed   (wins= 0/ 2) in 22 t-steps, @state  5, eps=0.04(6718), loss=0.3025
# Episode: 401/5000 --  failed   (wins= 0/ 2) in  7 t-steps, @state  5, eps=0.04(6725), loss=0.2682
# Episode: 402/5000 --  failed   (wins= 0/ 2) in 16 t-steps, @state 12, eps=0.04(6741), loss=0.2855
# Episode: 403/5000 --  failed   (wins= 0/ 2) in 19 t-steps, @state 12, eps=0.04(6760), loss=0.2460
# Episode: 404/5000 --  failed   (wins= 0/ 2) in 10 t-steps, @state  7, eps=0.04(6770), loss=0.3635
# Episode: 405/5000 --  failed   (wins= 0/ 2) in 73 t-steps, @state  5, eps=0.04(6843), loss=0.6733
# Episode: 406/5000 --  failed   (wins= 0/ 2) in 100 t-steps, @state  0, eps=0.04(6943), loss=0.3098
# Episode: 407/5000 -- *success* (wins= 1/ 2) in 13 t-steps, @state 15, eps=0.04(6956), loss=0.2758
# Episode: 408/5000 --  failed   (wins= 0/ 2) in  6 t-steps, @state  5, eps=0.04(6962), loss=0.2730
# Episode: 409/5000 --  failed   (wins= 0/ 2) in 44 t-steps, @state  7, eps=0.04(7006), loss=0.3270
# Episode: 410/5000 --  failed   (wins= 0/ 2) in 40 t-steps, @state  5, eps=0.04(7046), loss=0.2898
# Episode: 411/5000 -- *success* (wins= 1/ 2) in 39 t-steps, @state 15, eps=0.04(7085), loss=0.2959
# Episode: 412/5000 --  failed   (wins= 0/ 2) in 24 t-steps, @state  7, eps=0.04(7109), loss=0.4092
# Episode: 413/5000 -- *success* (wins= 1/ 2) in 23 t-steps, @state 15, eps=0.04(7132), loss=0.3595
# Episode: 414/5000 -- *success* (wins= 2/ 2) in 44 t-steps, @state 15, eps=0.03(7176), loss=0.2846
# Episode: 415/5000 --  failed   (wins= 0/ 2) in 28 t-steps, @state  5, eps=0.03(7204), loss=0.2868
# Episode: 416/5000 -- *success* (wins= 1/ 2) in 44 t-steps, @state 15, eps=0.03(7248), loss=0.2542
# Episode: 417/5000 -- *success* (wins= 2/ 2) in 25 t-steps, @state 15, eps=0.03(7273), loss=0.2616
# Episode: 418/5000 -- *success* (wins= 3/ 3) in 54 t-steps, @state 15, eps=0.03(7327), loss=0.3136
# Episode: 419/5000 -- *success* (wins= 4/ 4) in 41 t-steps, @state 15, eps=0.03(7368), loss=0.2481
# Episode: 420/5000 -- *success* (wins= 5/ 5) in 30 t-steps, @state 15, eps=0.03(7398), loss=0.2920
# Episode: 421/5000 --  failed   (wins= 0/ 5) in 11 t-steps, @state  7, eps=0.03(7409), loss=0.2653
# Episode: 422/5000 -- *success* (wins= 1/ 5) in 21 t-steps, @state 15, eps=0.03(7430), loss=0.3150
# Episode: 423/5000 -- *success* (wins= 2/ 5) in 25 t-steps, @state 15, eps=0.03(7455), loss=0.2628
# Episode: 424/5000 -- *success* (wins= 3/ 5) in 25 t-steps, @state 15, eps=0.03(7480), loss=0.3368
# Episode: 425/5000 -- *success* (wins= 4/ 5) in 37 t-steps, @state 15, eps=0.03(7517), loss=0.2454
# Episode: 426/5000 -- *success* (wins= 5/ 5) in 13 t-steps, @state 15, eps=0.03(7530), loss=0.2500
# Episode: 427/5000 --  failed   (wins= 0/ 5) in 31 t-steps, @state  5, eps=0.03(7561), loss=0.2539
# Episode: 428/5000 -- *success* (wins= 1/ 5) in 43 t-steps, @state 15, eps=0.03(7604), loss=0.2596
# Episode: 429/5000 -- *success* (wins= 2/ 5) in 37 t-steps, @state 15, eps=0.03(7641), loss=0.2599
# Episode: 430/5000 -- *success* (wins= 3/ 5) in 96 t-steps, @state 15, eps=0.03(7737), loss=0.3043
# Episode: 431/5000 -- *success* (wins= 4/ 5) in 67 t-steps, @state 15, eps=0.03(7804), loss=0.2933
# Episode: 432/5000 -- *success* (wins= 5/ 5) in 10 t-steps, @state 15, eps=0.03(7814), loss=0.2959
# Episode: 433/5000 --  failed   (wins= 0/ 5) in 17 t-steps, @state  7, eps=0.03(7831), loss=0.3428
# Episode: 434/5000 --  failed   (wins= 0/ 5) in 21 t-steps, @state  5, eps=0.03(7852), loss=0.3197
# Episode: 435/5000 -- *success* (wins= 1/ 5) in 40 t-steps, @state 15, eps=0.03(7892), loss=0.2499
# Episode: 436/5000 --  failed   (wins= 0/ 5) in 31 t-steps, @state  7, eps=0.03(7923), loss=0.2829
# Episode: 437/5000 --  failed   (wins= 0/ 5) in 17 t-steps, @state 12, eps=0.03(7940), loss=0.2450
# Episode: 438/5000 --  failed   (wins= 0/ 5) in 18 t-steps, @state 12, eps=0.03(7958), loss=0.3257
# Episode: 439/5000 --  failed   (wins= 0/ 5) in 57 t-steps, @state 12, eps=0.03(8015), loss=0.2503
# Episode: 440/5000 --  failed   (wins= 0/ 5) in 28 t-steps, @state 12, eps=0.03(8043), loss=0.2839
# Episode: 441/5000 --  failed   (wins= 0/ 5) in 18 t-steps, @state 12, eps=0.03(8061), loss=0.2378
# Episode: 442/5000 --  failed   (wins= 0/ 5) in 33 t-steps, @state  7, eps=0.03(8094), loss=0.2896
# Episode: 443/5000 --  failed   (wins= 0/ 5) in 100 t-steps, @state  9, eps=0.02(8194), loss=0.2418
# Episode: 444/5000 -- *success* (wins= 1/ 5) in 30 t-steps, @state 15, eps=0.02(8224), loss=0.2694
# Episode: 445/5000 --  failed   (wins= 0/ 5) in 33 t-steps, @state  7, eps=0.02(8257), loss=0.2761
# Episode: 446/5000 --  failed   (wins= 0/ 5) in 25 t-steps, @state  7, eps=0.02(8282), loss=0.2730
# Episode: 447/5000 --  failed   (wins= 0/ 5) in 12 t-steps, @state  5, eps=0.02(8294), loss=0.2522
# Episode: 448/5000 --  failed   (wins= 0/ 5) in 39 t-steps, @state  7, eps=0.02(8333), loss=0.2666
# Episode: 449/5000 -- *success* (wins= 1/ 5) in 45 t-steps, @state 15, eps=0.02(8378), loss=0.2686
# Episode: 450/5000 --  failed   (wins= 0/ 5) in 38 t-steps, @state  5, eps=0.02(8416), loss=0.2416
# Episode: 451/5000 -- *success* (wins= 1/ 5) in 30 t-steps, @state 15, eps=0.02(8446), loss=0.7337
# Episode: 452/5000 --  failed   (wins= 0/ 5) in 100 t-steps, @state  9, eps=0.02(8546), loss=0.5071
# Episode: 453/5000 --  failed   (wins= 0/ 5) in 34 t-steps, @state  7, eps=0.02(8580), loss=0.3454
# Episode: 454/5000 --  failed   (wins= 0/ 5) in 28 t-steps, @state  5, eps=0.02(8608), loss=0.2442
# Episode: 455/5000 --  failed   (wins= 0/ 5) in 25 t-steps, @state 12, eps=0.02(8633), loss=0.2487
# Episode: 456/5000 --  failed   (wins= 0/ 5) in 21 t-steps, @state  7, eps=0.02(8654), loss=0.2963
# Episode: 457/5000 -- *success* (wins= 1/ 5) in 81 t-steps, @state 15, eps=0.02(8735), loss=0.2139
# Episode: 458/5000 --  failed   (wins= 0/ 5) in 53 t-steps, @state  5, eps=0.02(8788), loss=0.2399
# Episode: 459/5000 -- *success* (wins= 1/ 5) in 24 t-steps, @state 15, eps=0.02(8812), loss=0.2644
# Episode: 460/5000 --  failed   (wins= 0/ 5) in  5 t-steps, @state  5, eps=0.02(8817), loss=0.2596
# Episode: 461/5000 -- *success* (wins= 1/ 5) in 10 t-steps, @state 15, eps=0.02(8827), loss=0.4630
# Episode: 462/5000 -- *success* (wins= 2/ 5) in 53 t-steps, @state 15, eps=0.02(8880), loss=0.8723
# Episode: 463/5000 --  failed   (wins= 0/ 5) in 61 t-steps, @state  5, eps=0.02(8941), loss=0.2423
# Episode: 464/5000 -- *success* (wins= 1/ 5) in 18 t-steps, @state 15, eps=0.02(8959), loss=0.2741
# Episode: 465/5000 --  failed   (wins= 0/ 5) in 53 t-steps, @state  5, eps=0.02(9012), loss=0.2529
# Episode: 466/5000 -- *success* (wins= 1/ 5) in 48 t-steps, @state 15, eps=0.02(9060), loss=0.3364
# Episode: 467/5000 -- *success* (wins= 2/ 5) in 38 t-steps, @state 15, eps=0.02(9098), loss=0.2916
# Episode: 468/5000 -- *success* (wins= 3/ 5) in 11 t-steps, @state 15, eps=0.02(9109), loss=0.3075
# Episode: 469/5000 -- *success* (wins= 4/ 5) in 27 t-steps, @state 15, eps=0.02(9136), loss=0.2770
# Episode: 470/5000 --  failed   (wins= 0/ 5) in 21 t-steps, @state  5, eps=0.02(9157), loss=0.2268
# Episode: 471/5000 -- *success* (wins= 1/ 5) in  8 t-steps, @state 15, eps=0.02(9165), loss=0.2949
# Episode: 472/5000 -- *success* (wins= 2/ 5) in 34 t-steps, @state 15, eps=0.02(9199), loss=0.2519
# Episode: 473/5000 --  failed   (wins= 0/ 5) in 24 t-steps, @state  7, eps=0.02(9223), loss=0.3704
# Episode: 474/5000 -- *success* (wins= 1/ 5) in 96 t-steps, @state 15, eps=0.02(9319), loss=0.2625
# Episode: 475/5000 -- *success* (wins= 2/ 5) in 15 t-steps, @state 15, eps=0.02(9334), loss=0.4780
# Episode: 476/5000 --  failed   (wins= 0/ 5) in  7 t-steps, @state  5, eps=0.02(9341), loss=0.2681
# Episode: 477/5000 -- *success* (wins= 1/ 5) in 15 t-steps, @state 15, eps=0.02(9356), loss=0.2979
# Episode: 478/5000 --  failed   (wins= 0/ 5) in  7 t-steps, @state  5, eps=0.02(9363), loss=0.2785
# Episode: 479/5000 --  failed   (wins= 0/ 5) in 76 t-steps, @state  5, eps=0.02(9439), loss=0.3217
# Episode: 480/5000 --  failed   (wins= 0/ 5) in 90 t-steps, @state  7, eps=0.02(9529), loss=0.3238
# Episode: 481/5000 --  failed   (wins= 0/ 5) in 12 t-steps, @state  7, eps=0.02(9541), loss=0.2574
# Episode: 482/5000 -- *success* (wins= 1/ 5) in 26 t-steps, @state 15, eps=0.02(9567), loss=0.3421
# Episode: 483/5000 -- *success* (wins= 2/ 5) in 68 t-steps, @state 15, eps=0.02(9635), loss=0.2707
# Episode: 484/5000 -- *success* (wins= 3/ 5) in 33 t-steps, @state 15, eps=0.02(9668), loss=0.2918
# Episode: 485/5000 -- *success* (wins= 4/ 5) in 15 t-steps, @state 15, eps=0.02(9683), loss=0.3073
# Episode: 486/5000 --  failed   (wins= 0/ 5) in 39 t-steps, @state  5, eps=0.02(9722), loss=0.2317
# Episode: 487/5000 -- *success* (wins= 1/ 5) in 35 t-steps, @state 15, eps=0.02(9757), loss=0.3381
# Episode: 488/5000 -- *success* (wins= 2/ 5) in 51 t-steps, @state 15, eps=0.02(9808), loss=0.3535
# Episode: 489/5000 -- *success* (wins= 3/ 5) in 35 t-steps, @state 15, eps=0.02(9843), loss=0.2500
# Episode: 490/5000 -- *success* (wins= 4/ 5) in 10 t-steps, @state 15, eps=0.02(9853), loss=0.2704
# Episode: 491/5000 --  failed   (wins= 0/ 5) in 15 t-steps, @state  5, eps=0.02(9868), loss=0.4032
# ...
# Episode:4841/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state  5, eps=0.01(142817), loss=0.2851
# Episode:4842/5000 --  failed   (wins= 0/ 9) in 27 t-steps, @state 11, eps=0.01(142844), loss=0.2171
# Episode:4843/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(142848), loss=0.2293
# Episode:4844/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state  5, eps=0.01(142853), loss=0.2156
# Episode:4845/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(142855), loss=0.1990
# Episode:4846/5000 --  failed   (wins= 0/ 9) in 77 t-steps, @state 11, eps=0.01(142932), loss=0.2348
# Episode:4847/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  5, eps=0.01(142938), loss=0.2163
# Episode:4848/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(142942), loss=0.2654
# Episode:4849/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state  7, eps=0.01(142960), loss=0.2260
# Episode:4850/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  7, eps=0.01(142970), loss=0.2495
# Episode:4851/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(142972), loss=0.2336
# Episode:4852/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(142976), loss=0.2013
# Episode:4853/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  5, eps=0.01(142983), loss=0.2061
# Episode:4854/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state 11, eps=0.01(142994), loss=0.3159
# Episode:4855/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(142998), loss=0.2856
# Episode:4856/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state  5, eps=0.01(143007), loss=0.1938
# Episode:4857/5000 --  failed   (wins= 0/ 9) in 12 t-steps, @state  5, eps=0.01(143019), loss=0.2087
# Episode:4858/5000 --  failed   (wins= 0/ 9) in 20 t-steps, @state  7, eps=0.01(143039), loss=0.2265
# Episode:4859/5000 --  failed   (wins= 0/ 9) in 23 t-steps, @state  7, eps=0.01(143062), loss=0.2266
# Episode:4860/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(143064), loss=0.3901
# Episode:4861/5000 --  failed   (wins= 0/ 9) in 13 t-steps, @state  5, eps=0.01(143077), loss=0.3565
# Episode:4862/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(143081), loss=0.2020
# Episode:4863/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state  5, eps=0.01(143092), loss=0.2078
# Episode:4864/5000 --  failed   (wins= 0/ 9) in 15 t-steps, @state  7, eps=0.01(143107), loss=0.1922
# Episode:4865/5000 --  failed   (wins= 0/ 9) in 24 t-steps, @state  7, eps=0.01(143131), loss=0.2042
# Episode:4866/5000 -- *success* (wins= 1/ 9) in  7 t-steps, @state 15, eps=0.01(143138), loss=0.1992
# Episode:4867/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  7, eps=0.01(143142), loss=0.1923
# Episode:4868/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  7, eps=0.01(143152), loss=0.3321
# Episode:4869/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state  5, eps=0.01(143170), loss=0.2067
# Episode:4870/5000 --  failed   (wins= 0/ 9) in 16 t-steps, @state  7, eps=0.01(143186), loss=0.1875
# Episode:4871/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(143188), loss=0.1809
# Episode:4872/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  7, eps=0.01(143198), loss=0.2865
# Episode:4873/5000 -- *success* (wins= 1/ 9) in 17 t-steps, @state 15, eps=0.01(143215), loss=0.2220
# Episode:4874/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state 11, eps=0.01(143223), loss=0.2491
# Episode:4875/5000 --  failed   (wins= 0/ 9) in 16 t-steps, @state  7, eps=0.01(143239), loss=0.2334
# Episode:4876/5000 --  failed   (wins= 0/ 9) in  3 t-steps, @state  5, eps=0.01(143242), loss=0.3177
# Episode:4877/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state 11, eps=0.01(143260), loss=0.2028
# Episode:4878/5000 -- *success* (wins= 1/ 9) in 10 t-steps, @state 15, eps=0.01(143270), loss=0.2334
# Episode:4879/5000 --  failed   (wins= 0/ 9) in 12 t-steps, @state  5, eps=0.01(143282), loss=0.2360
# Episode:4880/5000 --  failed   (wins= 0/ 9) in 35 t-steps, @state 11, eps=0.01(143317), loss=0.2105
# Episode:4881/5000 --  failed   (wins= 0/ 9) in 26 t-steps, @state  7, eps=0.01(143343), loss=0.2202
# Episode:4882/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state 11, eps=0.01(143361), loss=0.2747
# Episode:4883/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(143363), loss=0.1864
# Episode:4884/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state  5, eps=0.01(143372), loss=0.4369
# Episode:4885/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state 11, eps=0.01(143390), loss=0.2945
# Episode:4886/5000 --  failed   (wins= 0/ 9) in 24 t-steps, @state 11, eps=0.01(143414), loss=0.2264
# Episode:4887/5000 --  failed   (wins= 0/ 9) in 44 t-steps, @state  7, eps=0.01(143458), loss=0.2227
# Episode:4888/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state 11, eps=0.01(143465), loss=0.1871
# Episode:4889/5000 -- *success* (wins= 1/ 9) in 10 t-steps, @state 15, eps=0.01(143475), loss=0.1977
# Episode:4890/5000 --  failed   (wins= 0/ 9) in 33 t-steps, @state 11, eps=0.01(143508), loss=0.2479
# Episode:4891/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  7, eps=0.01(143515), loss=0.2081
# Episode:4892/5000 --  failed   (wins= 0/ 9) in 16 t-steps, @state 11, eps=0.01(143531), loss=0.2828
# Episode:4893/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state 11, eps=0.01(143539), loss=0.3180
# Episode:4894/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(143543), loss=0.1750
# Episode:4895/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(143545), loss=0.1866
# Episode:4896/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  5, eps=0.01(143552), loss=0.2595
# Episode:4897/5000 --  failed   (wins= 0/ 9) in 22 t-steps, @state 11, eps=0.01(143574), loss=0.2575
# Episode:4898/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state 11, eps=0.01(143580), loss=0.2184
# Episode:4899/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(143582), loss=0.4190
# Episode:4900/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state 11, eps=0.01(143587), loss=0.2026
# Episode:4901/5000 --  failed   (wins= 0/ 9) in 32 t-steps, @state  7, eps=0.01(143619), loss=0.3107
# Episode:4902/5000 --  failed   (wins= 0/ 9) in 14 t-steps, @state 12, eps=0.01(143633), loss=0.3381
# Episode:4903/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  5, eps=0.01(143641), loss=0.2161
# Episode:4904/5000 -- *success* (wins= 1/ 9) in 19 t-steps, @state 15, eps=0.01(143660), loss=0.2238
# Episode:4905/5000 --  failed   (wins= 0/ 9) in 21 t-steps, @state  7, eps=0.01(143681), loss=0.2041
# Episode:4906/5000 --  failed   (wins= 0/ 9) in 24 t-steps, @state  7, eps=0.01(143705), loss=0.2476
# Episode:4907/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state  7, eps=0.01(143716), loss=0.1710
# Episode:4908/5000 --  failed   (wins= 0/ 9) in 15 t-steps, @state  7, eps=0.01(143731), loss=0.1913
# Episode:4909/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  5, eps=0.01(143739), loss=0.1823
# Episode:4910/5000 --  failed   (wins= 0/ 9) in 19 t-steps, @state 11, eps=0.01(143758), loss=0.2722
# Episode:4911/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state  5, eps=0.01(143776), loss=0.2918
# Episode:4912/5000 --  failed   (wins= 0/ 9) in 12 t-steps, @state 11, eps=0.01(143788), loss=0.2773
# Episode:4913/5000 --  failed   (wins= 0/ 9) in 19 t-steps, @state  7, eps=0.01(143807), loss=0.2084
# Episode:4914/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(143811), loss=0.2684
# Episode:4915/5000 --  failed   (wins= 0/ 9) in  3 t-steps, @state  5, eps=0.01(143814), loss=0.1738
# Episode:4916/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state  5, eps=0.01(143819), loss=0.1824
# Episode:4917/5000 --  failed   (wins= 0/ 9) in 13 t-steps, @state  7, eps=0.01(143832), loss=0.1923
# Episode:4918/5000 --  failed   (wins= 0/ 9) in 15 t-steps, @state  7, eps=0.01(143847), loss=0.1900
# Episode:4919/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  7, eps=0.01(143851), loss=0.2063
# Episode:4920/5000 --  failed   (wins= 0/ 9) in 22 t-steps, @state  5, eps=0.01(143873), loss=0.2188
# Episode:4921/5000 -- *success* (wins= 1/ 9) in  7 t-steps, @state 15, eps=0.01(143880), loss=0.2182
# Episode:4922/5000 --  failed   (wins= 0/ 9) in 12 t-steps, @state 12, eps=0.01(143892), loss=0.3545
# Episode:4923/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  5, eps=0.01(143902), loss=0.3460
# Episode:4924/5000 --  failed   (wins= 0/ 9) in 33 t-steps, @state  5, eps=0.01(143935), loss=0.2477
# Episode:4925/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state 11, eps=0.01(143944), loss=0.2172
# Episode:4926/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state 11, eps=0.01(143953), loss=0.2649
# Episode:4927/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  5, eps=0.01(143961), loss=0.2192
# Episode:4928/5000 -- *success* (wins= 1/ 9) in 44 t-steps, @state 15, eps=0.01(144005), loss=0.2396
# Episode:4929/5000 -- *success* (wins= 2/ 9) in 11 t-steps, @state 15, eps=0.01(144016), loss=0.2558
# Episode:4930/5000 --  failed   (wins= 0/ 9) in 13 t-steps, @state  5, eps=0.01(144029), loss=0.1668
# Episode:4931/5000 --  failed   (wins= 0/ 9) in 31 t-steps, @state 11, eps=0.01(144060), loss=0.3293
# Episode:4932/5000 --  failed   (wins= 0/ 9) in 25 t-steps, @state  7, eps=0.01(144085), loss=0.2055
# Episode:4933/5000 --  failed   (wins= 0/ 9) in 56 t-steps, @state  7, eps=0.01(144141), loss=0.1869
# Episode:4934/5000 --  failed   (wins= 0/ 9) in  4 t-steps, @state  5, eps=0.01(144145), loss=0.2335
# Episode:4935/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144147), loss=0.3280
# Episode:4936/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state 11, eps=0.01(144157), loss=0.1865
# Episode:4937/5000 -- *success* (wins= 1/ 9) in 17 t-steps, @state 15, eps=0.01(144174), loss=0.1740
# Episode:4938/5000 -- *success* (wins= 2/ 9) in 25 t-steps, @state 15, eps=0.01(144199), loss=0.2165
# Episode:4939/5000 -- *success* (wins= 3/ 9) in  8 t-steps, @state 15, eps=0.01(144207), loss=0.2224
# Episode:4940/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144209), loss=0.3162
# Episode:4941/5000 --  failed   (wins= 0/ 9) in 14 t-steps, @state 11, eps=0.01(144223), loss=0.2146
# Episode:4942/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state 11, eps=0.01(144232), loss=0.1952
# Episode:4943/5000 -- *success* (wins= 1/ 9) in  7 t-steps, @state 15, eps=0.01(144239), loss=0.2759
# Episode:4944/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  5, eps=0.01(144245), loss=0.1961
# Episode:4945/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144247), loss=0.2515
# Episode:4946/5000 -- *success* (wins= 1/ 9) in  9 t-steps, @state 15, eps=0.01(144256), loss=0.2810
# Episode:4947/5000 -- *success* (wins= 2/ 9) in  8 t-steps, @state 15, eps=0.01(144264), loss=0.2010
# Episode:4948/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  5, eps=0.01(144271), loss=0.3839
# Episode:4949/5000 -- *success* (wins= 1/ 9) in 15 t-steps, @state 15, eps=0.01(144286), loss=0.3254
# Episode:4950/5000 --  failed   (wins= 0/ 9) in 31 t-steps, @state  5, eps=0.01(144317), loss=0.2581
# Episode:4951/5000 --  failed   (wins= 0/ 9) in 28 t-steps, @state 11, eps=0.01(144345), loss=0.2106
# Episode:4952/5000 -- *success* (wins= 1/ 9) in 16 t-steps, @state 15, eps=0.01(144361), loss=0.2063
# Episode:4953/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  7, eps=0.01(144368), loss=0.1988
# Episode:4954/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  7, eps=0.01(144374), loss=0.1854
# Episode:4955/5000 -- *success* (wins= 1/ 9) in  8 t-steps, @state 15, eps=0.01(144382), loss=0.4889
# Episode:4956/5000 --  failed   (wins= 0/ 9) in 21 t-steps, @state  5, eps=0.01(144403), loss=2.9368
# Episode:4957/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state  5, eps=0.01(144414), loss=0.2152
# Episode:4958/5000 -- *success* (wins= 1/ 9) in 16 t-steps, @state 15, eps=0.01(144430), loss=0.3014
# Episode:4959/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state  7, eps=0.01(144441), loss=0.2245
# Episode:4960/5000 -- *success* (wins= 1/ 9) in 42 t-steps, @state 15, eps=0.01(144483), loss=0.2854
# Episode:4961/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  5, eps=0.01(144490), loss=0.2108
# Episode:4962/5000 -- *success* (wins= 1/ 9) in 11 t-steps, @state 15, eps=0.01(144501), loss=0.1471
# Episode:4963/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  5, eps=0.01(144507), loss=0.2049
# Episode:4964/5000 --  failed   (wins= 0/ 9) in 59 t-steps, @state  5, eps=0.01(144566), loss=0.2036
# Episode:4965/5000 --  failed   (wins= 0/ 9) in 19 t-steps, @state  5, eps=0.01(144585), loss=0.1920
# Episode:4966/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state 12, eps=0.01(144591), loss=0.2141
# Episode:4967/5000 --  failed   (wins= 0/ 9) in 20 t-steps, @state 11, eps=0.01(144611), loss=0.2462
# Episode:4968/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144613), loss=0.3217
# Episode:4969/5000 -- *success* (wins= 1/ 9) in 11 t-steps, @state 15, eps=0.01(144624), loss=0.2077
# Episode:4970/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  5, eps=0.01(144634), loss=0.2545
# Episode:4971/5000 --  failed   (wins= 0/ 9) in 37 t-steps, @state  7, eps=0.01(144671), loss=0.2023
# Episode:4972/5000 -- *success* (wins= 1/ 9) in 16 t-steps, @state 15, eps=0.01(144687), loss=0.2153
# Episode:4973/5000 --  failed   (wins= 0/ 9) in 19 t-steps, @state  7, eps=0.01(144706), loss=0.2594
# Episode:4974/5000 --  failed   (wins= 0/ 9) in 37 t-steps, @state  7, eps=0.01(144743), loss=0.3351
# Episode:4975/5000 --  failed   (wins= 0/ 9) in 15 t-steps, @state  7, eps=0.01(144758), loss=0.1706
# Episode:4976/5000 --  failed   (wins= 0/ 9) in  9 t-steps, @state 11, eps=0.01(144767), loss=0.2448
# Episode:4977/5000 --  failed   (wins= 0/ 9) in 18 t-steps, @state 11, eps=0.01(144785), loss=0.2141
# Episode:4978/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state  7, eps=0.01(144790), loss=0.2288
# Episode:4979/5000 --  failed   (wins= 0/ 9) in 12 t-steps, @state  5, eps=0.01(144802), loss=0.2981
# Episode:4980/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state  5, eps=0.01(144812), loss=0.2331
# Episode:4981/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  5, eps=0.01(144820), loss=0.2218
# Episode:4982/5000 --  failed   (wins= 0/ 9) in  7 t-steps, @state  5, eps=0.01(144827), loss=0.3039
# Episode:4983/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  5, eps=0.01(144833), loss=0.2407
# Episode:4984/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state  5, eps=0.01(144839), loss=0.2605
# Episode:4985/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144841), loss=0.2191
# Episode:4986/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  5, eps=0.01(144849), loss=0.2368
# Episode:4987/5000 --  failed   (wins= 0/ 9) in 25 t-steps, @state  7, eps=0.01(144874), loss=0.1851
# Episode:4988/5000 --  failed   (wins= 0/ 9) in  2 t-steps, @state  5, eps=0.01(144876), loss=0.1969
# Episode:4989/5000 --  failed   (wins= 0/ 9) in  6 t-steps, @state 11, eps=0.01(144882), loss=0.2254
# Episode:4990/5000 -- *success* (wins= 1/ 9) in 25 t-steps, @state 15, eps=0.01(144907), loss=0.2357
# Episode:4991/5000 --  failed   (wins= 0/ 9) in 10 t-steps, @state 12, eps=0.01(144917), loss=0.2070
# Episode:4992/5000 --  failed   (wins= 0/ 9) in 23 t-steps, @state 11, eps=0.01(144940), loss=0.2237
# Episode:4993/5000 -- *success* (wins= 1/ 9) in 17 t-steps, @state 15, eps=0.01(144957), loss=0.2573
# Episode:4994/5000 --  failed   (wins= 0/ 9) in 20 t-steps, @state  5, eps=0.01(144977), loss=0.3323
# Episode:4995/5000 --  failed   (wins= 0/ 9) in 54 t-steps, @state 11, eps=0.01(145031), loss=0.2692
# Episode:4996/5000 --  failed   (wins= 0/ 9) in 11 t-steps, @state  5, eps=0.01(145042), loss=0.1840
# Episode:4997/5000 --  failed   (wins= 0/ 9) in 22 t-steps, @state 11, eps=0.01(145064), loss=0.2540
# Episode:4998/5000 --  failed   (wins= 0/ 9) in  5 t-steps, @state  5, eps=0.01(145069), loss=0.2581
# Episode:4999/5000 --  failed   (wins= 0/ 9) in  8 t-steps, @state  7, eps=0.01(145077), loss=0.2170
# Episode:5000/5000 --  failed   (wins= 0/ 9) in 16 t-steps, @state  5, eps=0.01(145093), loss=0.2026

# %%
# Once trained, put it to play
state = env.reset()
tot_r, done = 0, False
for ind_step in count():
    env.render()                    # Uncomment to see game running
    state = to_categorical(state, in_shape).reshape(-1, in_shape)
    action = net_policy.predict(state).argmax()
    state, reward, done, info = env.step(action)
    tot_r += reward
    if done:
        break
env.render()        
env.close()
print('Game ended! Total reward: {}'.format(tot_r))
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Game ended! Total reward: 1.0

# %%
# Save trained model for future use
#net_policy.save("net_policy.h5")

# %%
max_wins = 0
for i in range(1000):
  state = env.reset()
  done = False
  wins = 0
  for ind_step in count():
    #env.render()                    # Uncomment to see game running
    state = to_categorical(state, in_shape).reshape(-1, in_shape)
    action = net_policy.predict(state).argmax()
    state, reward, done, info = env.step(action)
    if done:
        break
  if reward == 1:
    wins += 1
  else:
    wins = 0
  max_wins = max(max_wins, wins)
env.close()

print('Max number of consecutive wins: {}'.format(max_wins))
# Out:
# Max number of consecutive wins: 1
